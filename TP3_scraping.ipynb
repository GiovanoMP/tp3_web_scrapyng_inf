# %% [markdown]
# **TP3 - Web Scraping**
#
# **Aluno Giovano Panatta**

# %% [markdown]
# # Parte 1 XPath - Acesse o arquivo XML em anexo
#
# Exercício 1:
#
# Utilize XPath absoluto com a biblioteca lxml para selecionar:
#
# O nome do diretor do segundo filme listado;
# O id do penúltimo filme listado, independentemente da quantidade de filmes na lista.

# %%
pip install --q lxml
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Estrutura Geral:
#
# O arquivo XML possui uma tag raiz chamada <library>, que contém duas seções principais: <books> e <movies>. Dentro de cada uma dessas seções, há uma lista de itens (<book> ou <movie>) que contêm informações sobre livros e filmes, respectivamente.
#
# 1. Seção de Livros (<books>):
# Esta seção contém uma lista de livros, representados pela tag <book>.
# Cada <book> tem dois atributos: id (um identificador único para o livro) e category (a categoria do livro, como "fantasy" ou "science_fiction").
# Cada <book> contém as seguintes informações:
# Título (<title>) – O nome do livro.
# Autor (<author>) – O nome do autor.
# Ano (<year>) – O ano de publicação.
# Preço (<price>) – O preço do livro, com o atributo currency indicando a moeda (USD, NZD, GBP).

# %%
# Importamos a função etree da biblioteca lxml, que nos permite trabalhar com XML e fazer consultas XPath
from lxml import etree

# Carregamos o arquivo XML (caminho absoluto)
tree = etree.parse("C:\infnet_ultimo_semestre\TP3_web_scraping\TP3.xml")

# XPath 1: Selecionando o nome do diretor do segundo filme
# O caminho absoluto até o nome do diretor é /library/movies/movie[2]/director
director_second_movie = tree.xpath('/library/movies/movie[2]/director/text()')[0]

# XPath 2: Selecionando o ID do penúltimo filme
# Usamos last()-1 para pegar o penúltimo item
penultimate_movie_id = tree.xpath('/library/movies/movie[last()-1]/@id')[0]

# Exibindo os resultados
print(f"Diretor do segundo filme: {director_second_movie}")
print(f"ID do penúltimo filme: {penultimate_movie_id}")
# Out:
# Diretor do segundo filme: Francis Ford Coppola
# ID do penúltimo filme: 102

# %% [markdown]
# # Exercício 2:
#
# Utilize XPath relativo com a biblioteca lxml para selecionar:
#
# Os títulos dos livros ou filmes da categoria fantasia;
#
# Os nomes (siglas) das moedas utilizadas nos preços que não são dólares americanos (USD);
#
# Os preços com valor numérico maior que 15 (independentemente da moeda);
#
# Todos os títulos que começam com "The".

# %%
from lxml import etree

# Carregando o arquivo XML (substitua com o caminho correto do arquivo)
tree = etree.parse("C:\infnet_ultimo_semestre\TP3_web_scraping\TP3.xml")


# Usamos XPath relativo para pegar títulos de livros ou filmes com category="fantasy"
titles_fantasy = tree.xpath('//book[@category="fantasy"]/title/text() | //movie[@category="fantasy"]/title/text()')


# Usamos XPath para selecionar o atributo currency de todos os elementos <price> que não são USD
non_usd_currencies = tree.xpath('//price[@currency!="USD"]/@currency')


# Utilizamos XPath para pegar o valor de texto dos elementos <price> cujo valor é maior que 15
prices_above_15 = tree.xpath('//price[number(text()) > 15]/text()')


# Utilizamos a função XPath starts-with() para pegar títulos que começam com "The"
titles_starting_with_the = tree.xpath('//title[starts-with(text(), "The")]/text()')

# Exibindo os resultados
print(f"Títulos da categoria fantasia: {titles_fantasy}")
print(f"Moedas que não são USD: {non_usd_currencies}")
print(f"Preços maiores que 15: {prices_above_15}")
print(f"Títulos que começam com 'The': {titles_starting_with_the}")
# Out:
# Títulos da categoria fantasia: ["Harry Potter and the Philosopher's Stone", 'The Hobbit']
# Moedas que não são USD: ['NZD', 'GBP', 'BRL']
# Preços maiores que 15: ['19.99', '15.99', '19.99']
# Títulos que começam com 'The': ['The Hobbit', 'The Godfather']

# %% [markdown]
# # Explicação sobre XPath Relativo com lxml
#
# **XPath Relativo** é uma técnica utilizada para navegar e extrair dados de documentos XML ou HTML sem precisar especificar o caminho completo desde a raiz. Ele é eficiente para selecionar elementos com base em atributos ou conteúdo, independentemente de sua posição exata na hierarquia do documento.
#
# ### Vantagens:
# - **Flexibilidade**: Permite selecionar elementos de qualquer lugar no documento, sem a necessidade de um caminho absoluto.
# - **Seleção específica**: Usamos expressões como `@atributo`, `text()`, e funções como `starts-with()` para buscar elementos com precisão.
#
# ### Exemplos práticos:
# - **`//book[@category="fantasy"]`**: Seleciona todos os livros da categoria "fantasia".
# - **`//price[@currency!="USD"]/@currency`**: Seleciona todas as moedas que não são USD.
# - **`//price[number(text()) > 15]`**: Seleciona preços maiores que 15.
# - **`//title[starts-with(text(), "The")]`**: Seleciona todos os títulos que começam com "The".
#
# Essa técnica é ideal para extrações específicas e eficientes, sem a necessidade de conhecer a estrutura exata do documento.

# %% [markdown]
# # Parte 2 Acesse o arquivo HTML em anexo
#
# # Exercício 3:
#
# Utilize (apenas) seletores de CSS com lxml para selecionar:
#
# Todos os nomes de países dos atletas;
# Todos os nomes de atletas que possuem a letra J (maiúscula);
# Todos os nomes de atletas dos EUA (USA) e da Rússia.

# %%
pip install lxml cssselect
# Out:
# Requirement already satisfied: lxml in c:\users\giova\appdata\local\programs\python\python311\lib\site-packages (5.2.2)
# Requirement already satisfied: cssselect in c:\users\giova\appdata\local\programs\python\python311\lib\site-packages (1.2.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# O arquivo HTML fornecido representa um "Dashboard de Desempenho de Atletas". Ele contém uma lista de cinco atletas, cada um com informações detalhadas sobre país, idade, desempenho em competições, e resultados de testes físicos. A estrutura segue um padrão de repetição para cada atleta, sendo que cada um é identificado por uma div com a classe "athlete" e um id único (athlete-1, athlete-2, etc.).

# %%
# Cada atleta tem as seguintes informações:
# 
# Nome: Está na tag h2 com a classe "name".
# País: Está no parágrafo <p> com a classe "country".
# Idade: Está no parágrafo <p> com a classe "age".
# Desempenho: Está no parágrafo <p> com a classe "performance", indicando a posição no ranking.
# Resultados dos Testes: Div com a classe "tests", contendo resultados de dois tipos de testes: velocidade e resistência.
#
# Essas informações estão organizadas em blocos repetidos para cada atleta. Vamos usar essa estrutura para selecionar dados utilizando seletores CSS.

# %%
from lxml import etree
from lxml.cssselect import CSSSelector

# Usando HTMLParser para processar HTML
parser = etree.HTMLParser()

# Carregando o arquivo HTML com o parser adequado
tree = etree.parse(r"C:\infnet_ultimo_semestre\TP3_web_scraping\TP3.html", parser)


# Selecionando todos os elementos <p> com a classe "country"
countries_selector = CSSSelector('.country')
countries = [country.text for country in countries_selector(tree)]


# Selecionando todos os elementos <h2> com a classe "name" e filtrando os que têm "J"
names_selector = CSSSelector('.name')
names_with_j = [name.text for name in names_selector(tree) if 'J' in name.text]

# Selecionando os atletas e filtrando pelos países "USA" e "Russia"
athletes_from_usa_russia = [
    name.text for name, country in zip(names_selector(tree), countries_selector(tree)) 
    if country.text in ['USA', 'Russia']
]

# Exibindo os resultados
print(f"Países dos atletas: {countries}")
print(f"Nomes de atletas com 'J': {names_with_j}")
print(f"Atletas dos EUA e Rússia: {athletes_from_usa_russia}")
# Out:
# Países dos atletas: ['USA', 'Canada', 'China', 'Mexico', 'Russia']
# Nomes de atletas com 'J': ['John Doe', 'Jane Smith']
# Atletas dos EUA e Rússia: ['John Doe', 'Olga Ivanova']

# %% [markdown]
# ### Por que usar seletores CSS?
# Os seletores CSS permitem uma maneira rápida e eficiente de **identificar e extrair elementos** de um arquivo HTML, com base em atributos como classes (`.class`), IDs (`#id`), ou a hierarquia dos elementos. São amplamente utilizados porque são simples e intuitivos, especialmente se você já trabalha com desenvolvimento web ou conhece CSS básico.
#
# ### Casos indicados para o uso de seletores CSS:
# - **Páginas HTML bem estruturadas**: Quando os elementos HTML estão organizados de forma consistente, com uso claro de classes e IDs.
# - **Extração específica**: Ideal para buscar dados com base em atributos, como todos os elementos que possuem uma classe ou ID específica.
# - **Scraping simples e direto**: Quando a estrutura da página é estável e você pode confiar na consistência do HTML ao longo do tempo.
#
# ### Casos em que seletores CSS não são recomendados:
# - **Páginas dinâmicas**: Quando o conteúdo da página é carregado via **JavaScript** (como em **Single Page Applications**), os seletores CSS podem não capturar o conteúdo, já que ele não estará presente no HTML inicial.
# - **Estruturas HTML inconsistentes**: Quando o HTML não segue um padrão claro de classes ou IDs, tornando difícil a extração precisa de dados.
# - **Manipulação de dados complexos**: Se a estrutura do documento é mais complexa, como no caso de documentos XML rigorosos, o **XPath** pode ser mais eficiente e preciso para navegar e extrair informações.
#
# ### Conclusão
# Seletores CSS são uma ótima ferramenta para **web scraping** quando se trabalha com páginas HTML bem organizadas e estáticas. No entanto, para páginas dinâmicas ou estruturas mais complexas, o uso de ferramentas mais robustas, como **Selenium** para páginas JavaScript ou **XPath** para navegação avançada, pode ser mais apropriado.

# %% [markdown]
# # Exercício 4:
#
# Utilize seletores de CSS com BeautifulSoup e algum tratamento em Python que seja necessário para alocar as informações de cada atleta do arquivo HTML em um dataframe do Pandas a ser salvo em arquivo CSV e então responda:
#
# A média de idades dos atletas;
# O atleta ganhador do Speed Test;
# O atleta ganhador do Endurance Test.

# %%
from bs4 import BeautifulSoup  # Usada para parsing do HTML
import pandas as pd  

# Abrindo o arquivo HTML e carregando seu conteúdo com BeautifulSoup
with open("C:\infnet_ultimo_semestre\TP3_web_scraping\TP3.html", "r", encoding="utf-8") as file:
    soup = BeautifulSoup(file, "html.parser")  # Carrega o conteúdo do HTML em um objeto BeautifulSoup

# Criamos uma lista para armazenar as informações de cada atleta
athletes = []

# Selecionamos todos os elementos <div> que possuem a classe "athlete" (ou seja, cada bloco de informações de um atleta)
athlete_divs = soup.select(".athlete")

# Iteramos sobre cada bloco de informações de atleta
for div in athlete_divs:
    # Extraímos o nome do atleta, contido na tag <h2> com a classe "name"
    name = div.select_one(".name").text
    
    # Extraímos o país do atleta, contido na tag <p> com a classe "country"
    country = div.select_one(".country").text
    
    # Extraímos a idade do atleta, contida na tag <p> com a classe "age" e convertemos para um inteiro
    age = int(div.select_one(".age").text)
    
    # Extraímos o resultado do Speed Test, contido na primeira tag <span> com a classe "result" (primeira ocorrência)
    speed_test = int(div.select(".test .result")[0].text)  # O primeiro teste listado é o de velocidade
    
    # Extraímos o resultado do Endurance Test, contido na segunda tag <span> com a classe "result" (segunda ocorrência)
    endurance_test = int(div.select(".test .result")[1].text)  # O segundo teste listado é o de resistência
    
    # Adicionamos todas essas informações em um dicionário e armazenamos na lista "athletes"
    athletes.append({
        "Name": name,
        "Country": country,
        "Age": age,
        "Speed Test": speed_test,
        "Endurance Test": endurance_test
    })

# Criamos um DataFrame do Pandas com a lista de atletas (cada dicionário vira uma linha)
df = pd.DataFrame(athletes)

# Salvamos o DataFrame em um arquivo CSV para persistir os dados
df.to_csv("athletes_data.csv", index=False)  # O parâmetro index=False garante que não seja salva uma coluna de índice

# Agora, realizamos as operações solicitadas para responder às perguntas:

# 1. Calculamos a média de idades dos atletas
average_age = df["Age"].mean()  # Usamos a função mean() do Pandas para calcular a média de idades

# 2. Encontramos o atleta com o maior resultado no Speed Test
# A função idxmax() retorna o índice da linha com o valor máximo na coluna "Speed Test"
# Usamos esse índice para pegar o nome do atleta ganhador
winner_speed_test = df.loc[df["Speed Test"].idxmax(), "Name"]

# 3. Encontramos o atleta com o maior resultado no Endurance Test
# Usamos a mesma lógica do Speed Test para encontrar o ganhador do Endurance Test
winner_endurance_test = df.loc[df["Endurance Test"].idxmax(), "Name"]

# Exibindo os resultados:
print(f"Média de idades dos atletas: {average_age:.2f}")  # Mostra a média com duas casas decimais
print(f"Atleta ganhador do Speed Test: {winner_speed_test}")
print(f"Atleta ganhador do Endurance Test: {winner_endurance_test}")
# Out:
# Média de idades dos atletas: 26.00
# Atleta ganhador do Speed Test: John Doe
# Atleta ganhador do Endurance Test: Jane Smith

# %% [markdown]
# # Explicação sobre o Uso de BeautifulSoup para Extração de Dados
#
# **BeautifulSoup** é uma biblioteca Python usada para **parsing** de documentos HTML e XML, facilitando a navegação e extração de dados de páginas web. No contexto deste exercício, ela foi usada para capturar informações de atletas como nome, país, idade e resultados de testes a partir de um arquivo HTML.
#
# ### Vantagens:
# - **Simplicidade**: Oferece uma sintaxe intuitiva para navegar em documentos HTML usando seletores CSS.
# - **Flexibilidade**: Pode lidar com HTML malformado, sendo mais permissiva que outras ferramentas de parsing.
# - **Integração com seletores CSS**: Permite selecionar elementos diretamente por classes e IDs, similar ao CSS usado em páginas web.
#
# ### Exemplos práticos:
# - **`.select_one(".name")`**: Seleciona o elemento que contém o nome do atleta com a classe `name`.
# - **`.select(".test .result")`**: Captura os resultados dos testes de velocidade e resistência, com base nas classes `test` e `result`.
# - **`.select(".athlete")`**: Seleciona todos os blocos de informações de cada atleta, que possuem a classe `athlete`.
#
# ### Integração com Pandas:
# Após extrair os dados com **BeautifulSoup**, eles são organizados em um **DataFrame do Pandas** para manipulação e análise, permitindo cálculos como a **média de idades** e a identificação dos atletas vencedores dos testes de velocidade e resistência.
#
# Essa técnica é ideal para **extração e estruturação de dados de páginas HTML**, facilitando o processamento e análise posterior com ferramentas como o Pandas.

# %% [markdown]
# # Parte 3 WebScraping
#
# ## Exercício 5:
#
# Acesse a URL https://www.scrapethissite.com/pages/simple/ e obtenha os dados de todos os países, salvando em um dataframe (sem utilizar o comando `pd.read_html`) com as seguintes colunas:
#
# Country;
# Capital;
# Population;
# Area.

# %% [markdown]
# # Estrutura do Site
#
# O site contém informações sobre países organizadas em blocos de `div` com a classe `.country`. Cada bloco apresenta os seguintes elementos:
#
# - **Nome do país**: Dentro de uma tag `<h3>` com a classe `.country-name`.
# - **Capital**: Dentro de um `span` com a classe `.country-capital`.
# - **População**: Dentro de um `span` com a classe `.country-population`.
# - **Área**: Dentro de um `span` com a classe `.country-area`.
#
# Esses blocos estão agrupados dentro de várias `divs` com a classe `.col-md-4 country`. Isso permite que os dados sejam extraídos de maneira consistente, com base nas classes CSS específicas para cada informação.

# %%
import requests
from bs4 import BeautifulSoup


# URL da página que vamos acessar
url = "https://www.scrapethissite.com/pages/simple/"

# Realizando a requisição GET para a página
response = requests.get(url)

# Verificamos se a requisição foi bem-sucedida (status code 200)
if response.status_code == 200:
    # Parsing do conteúdo da página HTML com BeautifulSoup
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Criamos uma lista para armazenar as informações de cada país
    countries_data = []
    
    # Selecionamos todas as divs que contém informações dos países (classe "country")
    country_divs = soup.select(".country")
    
    # Iteramos sobre cada div de país e extraímos as informações relevantes
    for country_div in country_divs:
        # Nome do país
        country_name = country_div.select_one(".country-name").text.strip()
        
        # Capital do país
        capital = country_div.select_one(".country-capital").text.strip()
        
        # População do país
        population = country_div.select_one(".country-population").text.strip()
        
        # Área do país
        area = country_div.select_one(".country-area").text.strip()
        
        # Adicionamos os dados a uma lista como dicionário
        countries_data.append({
            "Country": country_name,
            "Capital": capital,
            "Population": population,
            "Area": area
        })
    
    # Criamos um DataFrame com os dados dos países
    df = pd.DataFrame(countries_data)
    
    # Salvamos o DataFrame em um arquivo CSV
    df.to_csv("countries_data.csv", index=False)
    
    # Exibindo o DataFrame
    print(df)
else:
    print(f"Erro ao acessar a página. Status code: {response.status_code}")
# Out:
#                   Country           Capital Population       Area
# 0                 Andorra  Andorra la Vella      84000      468.0
# 1    United Arab Emirates         Abu Dhabi    4975593    82880.0
# 2             Afghanistan             Kabul   29121286   647500.0
# 3     Antigua and Barbuda        St. John's      86754      443.0
# 4                Anguilla        The Valley      13254      102.0
# ..                    ...               ...        ...        ...
# 245                 Yemen             Sanaa   23495361   527970.0
# 246               Mayotte         Mamoudzou     159042      374.0
# 247          South Africa          Pretoria   49000000  1219912.0
# 248                Zambia            Lusaka   13460305   752614.0
# 249              Zimbabwe            Harare   11651858   390580.0
#
# [250 rows x 4 columns]

# %% [markdown]
# # Explicação sobre o uso do BeautifulSoup no exercício acima
#
# **BeautifulSoup** é utilizado para fazer o **parsing** do HTML da página e permitir a navegação e extração dos dados. Neste caso específico, usamos seletores CSS para localizar os elementos desejados:
#
# - **`.select(".country")`**: Seleciona todos os blocos de países.
# - **`.select_one(".country-name")`**: Extrai o nome do país.
# - **`.select_one(".country-capital")`**: Extrai a capital do país.
# - **`.select_one(".country-population")`**: Extrai a população do país.
# - **`.select_one(".country-area")`**: Extrai a área do país.
#
# Após a extração dos dados, eles são organizados em uma lista de dicionários, que é convertida em um **DataFrame do Pandas** para fácil manipulação e análise.

# %% [markdown]
# # Exercício 6:
#
# Escolha uma notícia qualquer do site https://www.romanews.com.br/ e obtenha o HTML da página via requisição utilizando a biblioteca que preferir (`urllib`, `requests`, etc.), salvando o arquivo no seu diretório. Então, a partir do arquivo HTML da notícia salva, construa códigos em Python utilizando `BeautifulSoup` para obter e salvar em um arquivo JSON, junto à URL da notícia e ao datetime do momento da requisição da página (os objetos datetime devem ter a informação da timezone e ser colocados em isoformat no momento de gerar o JSON):
#
# O objeto datetime da data e hora da publicação da notícia (dica: é sempre bom checar as tags `meta` dentro do `head` do arquivo.);
# O título da notícia;
# O corpo do texto da notícia;
# O subtítulo da notícia (se houver);
# O autor ou autores da notícia (se houver).

# %%
pip install -q selenium
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from bs4 import BeautifulSoup
import json
from datetime import datetime
import pytz
import time
import os

# URL da notícia que queremos capturar
url = "https://www.romanews.com.br/cidades/pesquisas-da-uepa-ajudam-na-fiscalizacao-de-transporte-e-comercializacao-da-madeira-no-para-0924"

# Caminho completo para o ChromeDriver (certifique-se de que o caminho está correto)
chromedriver_path = r"C:\Program Files\chromedriver-win64\chromedriver.exe"

# Inicializamos o WebDriver do Selenium com a classe Service
service = Service(chromedriver_path)
driver = webdriver.Chrome(service=service)

# Acessamos a URL da notícia utilizando o WebDriver do Selenium
driver.get(url)

# Pausamos a execução por alguns segundos para garantir que a página tenha tempo suficiente para carregar todo o conteúdo
time.sleep(5)

# Capturamos o HTML da página carregada pelo navegador controlado pelo Selenium
page_content = driver.page_source

# Fechamos o WebDriver para liberar o navegador e evitar que ele continue aberto
driver.quit()

# Salvamos o HTML capturado em um arquivo local para referência futura
html_file_path = "noticia_romanews.html"
with open(html_file_path, "w", encoding="utf-8") as file:
    file.write(page_content)

# Parsing do conteúdo HTML capturado usando BeautifulSoup
soup = BeautifulSoup(page_content, "html.parser")

# Obter o datetime da requisição com timezone
timezone = pytz.timezone('America/Sao_Paulo')
request_datetime = datetime.now(timezone).isoformat()

# Capturando a data de publicação do meta tag
pub_datetime_tag = soup.find("meta", {"name": "cXenseParse:recs:publishtime"})
pub_datetime = pub_datetime_tag["content"] if pub_datetime_tag else "Data de publicação não encontrada"

# Capturando o título da notícia a partir da tag <title>
title_tag = soup.find("title")
title = title_tag.text.strip() if title_tag else "Título não encontrado"

# Extraindo o corpo da notícia (isso pode precisar de ajuste dependendo do HTML completo)
body_tag = soup.find("div", class_="corpo")  # Ajuste necessário para capturar o corpo real
body = body_tag.get_text(separator=" ").strip() if body_tag else "Corpo da notícia não encontrado"

# Criar um dicionário com os dados extraídos da notícia
news_data = {
    "url": url,
    "request_datetime": request_datetime,
    "publication_datetime": pub_datetime,
    "title": title,
    "body": body
}

# Verificar se a pasta 'resultados' existe, senão, criá-la
if not os.path.exists('resultados'):
    os.makedirs('resultados')

# Salvamos o dicionário em um arquivo JSON dentro da pasta 'resultados'
json_file_path = os.path.join('resultados', "noticia_selenium.json")
with open(json_file_path, "w", encoding="utf-8") as json_file:
    json.dump(news_data, json_file, ensure_ascii=False, indent=4)

print(f"Notícia salva com sucesso no arquivo {json_file_path}")
# Out:
# Notícia salva com sucesso no arquivo resultados\noticia_selenium.json

# %% [markdown]
# ## O que é o Selenium?
# Selenium é uma biblioteca usada para automatizar navegadores da web, simulando ações como navegar para uma URL, clicar em botões, preencher formulários e, no nosso caso, capturar o conteúdo dinâmico de uma página.
#
# ## Quando utilizar Selenium?
# Utilizamos Selenium quando o conteúdo da página é gerado dinamicamente via JavaScript, ou seja, quando a página carrega elementos após a inicialização (algo comum em sites modernos). Outras bibliotecas como `requests` ou `urllib` não conseguem capturar esses conteúdos dinâmicos. O Selenium abre um navegador real (ou sem interface gráfica) para interagir com o conteúdo exatamente como um usuário faria.
#
# ### Vantagens do Selenium:
# - **Captura de conteúdo dinâmico**: Ideal para sites que usam JavaScript para carregar ou modificar o conteúdo.
# - **Simulação de ações do usuário**: Podemos navegar, clicar, preencher formulários, e muito mais.
# - **Flexibilidade**: Funciona em diversos navegadores (Chrome, Firefox, etc.) e oferece controle completo da página.
#
# ### Desvantagens:
# - **Mais lento que requests/urllib**: Por controlar um navegador real, a execução do Selenium é mais lenta.
# - **Dependência de WebDriver**: Precisamos configurar corretamente o WebDriver (como o ChromeDriver no nosso caso).
#
# ## Contexto do código:
# 1. **Selenium é utilizado** para carregar dinamicamente a página de uma notícia da web (Romanews) e capturar o HTML completo.
# 2. **BeautifulSoup** é então utilizado para fazer o parsing desse HTML e extrair dados específicos, como o título, autor, e data de publicação.
# 3. **Json e os**: Os dados extraídos são salvos em um arquivo JSON, garantindo que podemos reutilizar essas informações posteriormente.
# 4. **time e datetime**: Garantimos que a página tenha tempo para carregar com `time.sleep()`, e usamos `datetime` para registrar o momento exato da requisição, incluindo o fuso horário com `pytz`.
#
# ### Por que Selenium foi necessário aqui?
# O site Romanews possivelmente carrega partes do conteúdo de forma dinâmica (via JavaScript), e com Selenium conseguimos garantir que o navegador tenha carregado todo o conteúdo antes de extraí-lo.

# %% [markdown]
# # Parte 4 WebCrawling
#
# ## Exercício 8:
#
# Examine o site https://difusoranews.com/ e descubra o padrão de URL para paginação que ele aceita (dica: considere tentativa-e-erro). Então, utilize-o para obter uma lista de links de notícias requisitando as cinco primeiras páginas e raspando os links através de um único seletor de CSS aplicado via `BeautifulSoup`.

# %%
import requests
from bs4 import BeautifulSoup

# Padrões de URL para testar
pagination_patterns = [
    "https://difusoranews.com/page/{}",       # Padrão 1
    "https://difusoranews.com/?pagina={}",    # Padrão 2
    "https://difusoranews.com/p/{}",          # Padrão 3
    "https://difusoranews.com/?pg={}",        # Padrão 4
    "https://difusoranews.com/index/page/{}", # Padrão 5
    "https://difusoranews.com/index?page={}", # Padrão 6
    "https://difusoranews.com/list/page/{}",  # Padrão 7
    "https://difusoranews.com/?step={}",      # Padrão 8
]

# Função para verificar se a página retornada é diferente da página inicial
def is_valid_pagination(soup_initial, soup_page):
    # Tentamos comparar algo único, como o título da página ou o número de links
    return soup_initial != soup_page

# Obter o conteúdo da página inicial
response_initial = requests.get("https://difusoranews.com")
soup_initial = BeautifulSoup(response_initial.content, "html.parser")

# Loop pelos padrões de URL
for pattern in pagination_patterns:
    for page_num in range(1, 6):  # Testando até a 5ª página
        url = pattern.format(page_num)
        print(f"Tentando URL: {url}")
        response = requests.get(url)
        
        if response.status_code == 200:
            soup_page = BeautifulSoup(response.content, "html.parser")
            
            # Verifica se a página é diferente da inicial
            if is_valid_pagination(soup_initial, soup_page):
                print(f"Página {page_num} encontrada com o padrão: {url}")
            else:
                print(f"A página {page_num} com o padrão {url} parece ser igual à página inicial.")
        else:
            print(f"Erro ao tentar acessar {url}: Status {response.status_code}")

print("Teste de padrões de URL concluído.")
# Out:
# Tentando URL: https://difusoranews.com/page/1
# A página 1 com o padrão https://difusoranews.com/page/1 parece ser igual à página inicial.
# Tentando URL: https://difusoranews.com/page/2
# Página 2 encontrada com o padrão: https://difusoranews.com/page/2
# Tentando URL: https://difusoranews.com/page/3
# Página 3 encontrada com o padrão: https://difusoranews.com/page/3
# Tentando URL: https://difusoranews.com/page/4
# Página 4 encontrada com o padrão: https://difusoranews.com/page/4
# Tentando URL: https://difusoranews.com/page/5
# Página 5 encontrada com o padrão: https://difusoranews.com/page/5
# Tentando URL: https://difusoranews.com/?pagina=1
# Página 1 encontrada com o padrão: https://difusoranews.com/?pagina=1
# Tentando URL: https://difusoranews.com/?pagina=2
# Página 2 encontrada com o padrão: https://difusoranews.com/?pagina=2
# Tentando URL: https://difusoranews.com/?pagina=3
# Página 3 encontrada com o padrão: https://difusoranews.com/?pagina=3
# Tentando URL: https://difusoranews.com/?pagina=4
# Página 4 encontrada com o padrão: https://difusoranews.com/?pagina=4
# Tentando URL: https://difusoranews.com/?pagina=5
# Página 5 encontrada com o padrão: https://difusoranews.com/?pagina=5
# Tentando URL: https://difusoranews.com/p/1
# Erro ao tentar acessar https://difusoranews.com/p/1: Status 404
# Tentando URL: https://difusoranews.com/p/2
# Erro ao tentar acessar https://difusoranews.com/p/2: Status 404
# Tentando URL: https://difusoranews.com/p/3
# Erro ao tentar acessar https://difusoranews.com/p/3: Status 404
# Tentando URL: https://difusoranews.com/p/4
# Erro ao tentar acessar https://difusoranews.com/p/4: Status 404
# Tentando URL: https://difusoranews.com/p/5
# Erro ao tentar acessar https://difusoranews.com/p/5: Status 404
# Tentando URL: https://difusoranews.com/?pg=1
# Página 1 encontrada com o padrão: https://difusoranews.com/?pg=1
# Tentando URL: https://difusoranews.com/?pg=2
# Página 2 encontrada com o padrão: https://difusoranews.com/?pg=2
# Tentando URL: https://difusoranews.com/?pg=3
# Página 3 encontrada com o padrão: https://difusoranews.com/?pg=3
# Tentando URL: https://difusoranews.com/?pg=4
# Página 4 encontrada com o padrão: https://difusoranews.com/?pg=4
# Tentando URL: https://difusoranews.com/?pg=5
# Página 5 encontrada com o padrão: https://difusoranews.com/?pg=5
# Tentando URL: https://difusoranews.com/index/page/1
# Erro ao tentar acessar https://difusoranews.com/index/page/1: Status 404
# Tentando URL: https://difusoranews.com/index/page/2
# Erro ao tentar acessar https://difusoranews.com/index/page/2: Status 404
# Tentando URL: https://difusoranews.com/index/page/3
# Erro ao tentar acessar https://difusoranews.com/index/page/3: Status 404
# Tentando URL: https://difusoranews.com/index/page/4
# Erro ao tentar acessar https://difusoranews.com/index/page/4: Status 404
# Tentando URL: https://difusoranews.com/index/page/5
# Erro ao tentar acessar https://difusoranews.com/index/page/5: Status 404
# Tentando URL: https://difusoranews.com/index?page=1
# Erro ao tentar acessar https://difusoranews.com/index?page=1: Status 404
# Tentando URL: https://difusoranews.com/index?page=2
# Erro ao tentar acessar https://difusoranews.com/index?page=2: Status 404
# Tentando URL: https://difusoranews.com/index?page=3
# Erro ao tentar acessar https://difusoranews.com/index?page=3: Status 404
# Tentando URL: https://difusoranews.com/index?page=4
# Erro ao tentar acessar https://difusoranews.com/index?page=4: Status 404
# Tentando URL: https://difusoranews.com/index?page=5
# Erro ao tentar acessar https://difusoranews.com/index?page=5: Status 404
# Tentando URL: https://difusoranews.com/list/page/1
# Erro ao tentar acessar https://difusoranews.com/list/page/1: Status 404
# Tentando URL: https://difusoranews.com/list/page/2
# Erro ao tentar acessar https://difusoranews.com/list/page/2: Status 404
# Tentando URL: https://difusoranews.com/list/page/3
# Erro ao tentar acessar https://difusoranews.com/list/page/3: Status 404
# Tentando URL: https://difusoranews.com/list/page/4
# Erro ao tentar acessar https://difusoranews.com/list/page/4: Status 404
# Tentando URL: https://difusoranews.com/list/page/5
# Erro ao tentar acessar https://difusoranews.com/list/page/5: Status 404
# Tentando URL: https://difusoranews.com/?step=1
# Página 1 encontrada com o padrão: https://difusoranews.com/?step=1
# Tentando URL: https://difusoranews.com/?step=2
# Página 2 encontrada com o padrão: https://difusoranews.com/?step=2
# Tentando URL: https://difusoranews.com/?step=3
# Página 3 encontrada com o padrão: https://difusoranews.com/?step=3
# Tentando URL: https://difusoranews.com/?step=4
# Página 4 encontrada com o padrão: https://difusoranews.com/?step=4
# Tentando URL: https://difusoranews.com/?step=5
# Página 5 encontrada com o padrão: https://difusoranews.com/?step=5
# Teste de padrões de URL concluído.

# %%
import requests
from bs4 import BeautifulSoup

# URL base e padrão de paginação identificado
base_url = "https://difusoranews.com/page/{}/"

# Lista para armazenar os links das notícias
news_links = []

# Função para extrair links das notícias de uma página
def extract_news_links(soup):
    # Usando o seletor CSS que identifica os links das notícias
    # Aqui estamos assumindo que os links das notícias estão em <a> tags dentro de <h2> (ou outro padrão que você identificar no site)
    for article in soup.select('h2 a'):
        news_links.append(article['href'])

# Loop para percorrer as 5 primeiras páginas
for page_num in range(1, 6):
    url = base_url.format(page_num)
    print(f"Acessando: {url}")
    
    # Requisição HTTP para obter o conteúdo da página
    response = requests.get(url)
    
    if response.status_code == 200:
        # Parsing do conteúdo da página com BeautifulSoup
        soup = BeautifulSoup(response.content, "html.parser")
        
        # Extração dos links de notícias dessa página
        extract_news_links(soup)
        
        print(f"Links extraídos da página {page_num}: {len(news_links)} até agora")
    else:
        print(f"Erro ao acessar a página {page_num}. Status code: {response.status_code}")

# Exibindo os links extraídos
print("Lista final de links de notícias extraídos:")
for link in news_links:
    print(link)

# Opcional: Salvando os links em um arquivo de texto
with open('news_links.txt', 'w') as file:
    for link in news_links:
        file.write(link + "\n")

print("Links de notícias salvos em 'news_links.txt'.")
# Out:
# Acessando: https://difusoranews.com/page/1/
# Links extraídos da página 1: 0 até agora
# Acessando: https://difusoranews.com/page/2/
# Links extraídos da página 2: 0 até agora
# Acessando: https://difusoranews.com/page/3/
# Links extraídos da página 3: 0 até agora
# Acessando: https://difusoranews.com/page/4/
# Links extraídos da página 4: 0 até agora
# Acessando: https://difusoranews.com/page/5/
# Links extraídos da página 5: 0 até agora
# Lista final de links de notícias extraídos:
# Links de notícias salvos em 'news_links.txt'.

# %%
import requests
from bs4 import BeautifulSoup

# Padrão de paginação identificado
pagination_pattern = "https://difusoranews.com/page/{}"

# Função para extrair links de notícias
def extract_news_links(soup):
    news_links = []
    # Seleciona todos os elementos <a> dentro da tag <main>, que podem conter as notícias
    for link in soup.select("main a[href]"):
        href = link.get("href")
        if href and href.startswith("https://difusoranews.com/") and href not in news_links:
            news_links.append(href)
    return news_links

# Lista para armazenar todos os links de notícias
all_news_links = []

# Loop pelas 5 primeiras páginas
for page_num in range(1, 6):
    url = pagination_pattern.format(page_num)
    print(f"Acessando URL: {url}")
    response = requests.get(url)
    
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, "html.parser")
        # Extrair os links de notícias da página atual
        news_links = extract_news_links(soup)
        if news_links:
            print(f"Links encontrados na página {page_num}: {news_links}")
            all_news_links.extend(news_links)  # Adicionar os links à lista total
        else:
            print(f"Nenhum link encontrado na página {page_num}.")
    else:
        print(f"Erro ao acessar a página {url}: Status {response.status_code}")

# Salvando os links em um arquivo txt
with open("news_link.txt", "w") as f:
    for link in all_news_links:
        f.write(link + "\n")

print("Links de notícias extraídos e salvos em 'news_link.txt'.")
# Out:
# Acessando URL: https://difusoranews.com/page/1
# Links encontrados na página 1: ['https://difusoranews.com/eleicoes-2024/sabatina/saulo-arcangeli-defende-reducao-de-salario-e-criacao-de-empresa-de-onibus-da-prefeitura/', 'https://difusoranews.com/eleicoes-2024/sabatina/', 'https://difusoranews.com/eleicoes-2024/', 'https://difusoranews.com/eleicoes-2024/pesquisa-mostra-josinaldo-moraes-liderando-corrida-eleitoral-em-santa-helena/', 'https://difusoranews.com/oportunidade/', 'https://difusoranews.com/oportunidade/sextou-no-painel-de-emprego-com-vaga-para-fisioterapeuta/', 'https://difusoranews.com/eleicoes-2024/candidatos-a-prefeitura-de-sao-luis-divulgam-agenda-desta-sexta-feira-13/', 'https://difusoranews.com/esportes/rayssa-leal-garante-vaga-para-semifinal-do-mundial-de-skate-street-em-roma/', 'https://difusoranews.com/esportes/', 'https://difusoranews.com/eleicoes-2024/jhulio-sousa-lidera-disputa-pela-prefeitura-de-pocao-de-pedras-diz-pesquisa/', 'https://difusoranews.com/eleicoes-2024/nova-pesquisa-mostra-cenario-da-corrida-eleitoral-em-pinheiro/', 'https://difusoranews.com/transito/', 'https://difusoranews.com/transito/video-motociclista-tenta-ultrapassagem-bate-em-outra-moto-e-mata-mulher-na-raposa/', 'https://difusoranews.com/eleicoes-2024/pesquisa-aponta-cenario-da-disputa-pela-prefeitura-de-imperatriz/', 'https://difusoranews.com/policia/', 'https://difusoranews.com/policia/homem-disfarcado-de-policial-assalta-agencia-bancaria-em-pinheiro/', 'https://difusoranews.com/maranhao/rodovia-federal/motorista-provoca-engavetamento-na-br-010-apos-dirigir-por-24h-sem-parar/', 'https://difusoranews.com/maranhao/rodovia-federal/', 'https://difusoranews.com/maranhao/banco-do-nordeste-cultural-inaugura-exposicao-nordeste-expandido-em-sao-luis/', 'https://difusoranews.com/maranhao/', 'https://difusoranews.com/maranhao/transporte-publico/onibus-estao-todos-velhos-diz-morador-da-regiao-itaqui-bacanga/', 'https://difusoranews.com/maranhao/transporte-publico/', 'https://difusoranews.com/economia/', 'https://difusoranews.com/economia/aneel-reduz-patamar-de-bandeira-vermelha-e-aumento-pode-ser-menor/', 'https://difusoranews.com/economia/lotomania-uma-aposta-em-sao-luis-faturou-o-premio-de-r73-mil/', 'https://difusoranews.com/economia/receita-federal-divulga-edital-do-leilao-eletronico-2024/', 'https://difusoranews.com/economia/aneel-aprova-reducao-na-tarifa-de-energia-eletrica-dos-consumidores-residenciais-do-maranhao/', 'https://difusoranews.com/economia/servicos/plataforma-tem-crescimento-de-100-em-hospedagem-com-pets/', 'https://difusoranews.com/eleicoes-2024/propaganda-eleitoral-em-postes-e-medidores-de-energia-e-proibida-saiba-como-denunciar/', 'https://difusoranews.com/policia/amigos-exibem-dinheiro-de-aposta-na-internet-e-sao-assaltados-em-caxias/', 'https://difusoranews.com/transito/motorista-morre-apos-carro-bater-em-muro-e-capotar-em-sao-luis/', 'https://difusoranews.com/maranhao/sao-luis/moradores-denunciam-descaso-e-abandono-no-mercado-da-forquilha/', 'https://difusoranews.com/maranhao/sao-luis/', 'https://difusoranews.com/maranhao/sao-luis/agenda-dos-candidatos-a-prefeitura-de-sao-luis-para-quinta-feira-12/', 'https://difusoranews.com/maranhao/radio-clandestina-e-fechada-pela-policia-federal-em-anapurus/', 'https://difusoranews.com/policia/adolescente-e-apreendido-por-envolvimento-em-roubo-a-moto-na-cohab/', 'https://difusoranews.com/eleicoes-2024/sabatina/candidato-eduardo-braide-falta-a-sabatina-do-grupo-difusora/', 'https://difusoranews.com/ao-vivo/', 'https://difusoranews.com/ao-vivo/imperatriz/', 'https://difusoranews.com/ao-vivo/caxias/', 'https://difusoranews.com/difusora-fm/', 'https://difusoranews.com/difusora-fm/imperatriz/', 'https://difusoranews.com/difusora-fm/caxias/', 'https://difusoranews.com/difusora-news-fm/', 'https://difusoranews.com/maranhao/maioria-dos-acidentes-de-transito-do-estado-envolve-motos-diz-senatran/', 'https://difusoranews.com/policia/video-homem-tenta-prestar-ajuda-e-e-roubado-em-sao-luis/', 'https://difusoranews.com/policia/seguranca-publi ...
# Acessando URL: https://difusoranews.com/page/2
# Links encontrados na página 2: ['https://difusoranews.com/eleicoes-2024/sabatina/saulo-arcangeli-defende-reducao-de-salario-e-criacao-de-empresa-de-onibus-da-prefeitura/', 'https://difusoranews.com/eleicoes-2024/sabatina/', 'https://difusoranews.com/eleicoes-2024/', 'https://difusoranews.com/eleicoes-2024/pesquisa-mostra-josinaldo-moraes-liderando-corrida-eleitoral-em-santa-helena/', 'https://difusoranews.com/oportunidade/', 'https://difusoranews.com/oportunidade/sextou-no-painel-de-emprego-com-vaga-para-fisioterapeuta/', 'https://difusoranews.com/eleicoes-2024/candidatos-a-prefeitura-de-sao-luis-divulgam-agenda-desta-sexta-feira-13/', 'https://difusoranews.com/esportes/rayssa-leal-garante-vaga-para-semifinal-do-mundial-de-skate-street-em-roma/', 'https://difusoranews.com/esportes/', 'https://difusoranews.com/eleicoes-2024/jhulio-sousa-lidera-disputa-pela-prefeitura-de-pocao-de-pedras-diz-pesquisa/', 'https://difusoranews.com/eleicoes-2024/nova-pesquisa-mostra-cenario-da-corrida-eleitoral-em-pinheiro/', 'https://difusoranews.com/transito/', 'https://difusoranews.com/transito/video-motociclista-tenta-ultrapassagem-bate-em-outra-moto-e-mata-mulher-na-raposa/', 'https://difusoranews.com/eleicoes-2024/pesquisa-aponta-cenario-da-disputa-pela-prefeitura-de-imperatriz/', 'https://difusoranews.com/policia/', 'https://difusoranews.com/policia/homem-disfarcado-de-policial-assalta-agencia-bancaria-em-pinheiro/', 'https://difusoranews.com/maranhao/rodovia-federal/motorista-provoca-engavetamento-na-br-010-apos-dirigir-por-24h-sem-parar/', 'https://difusoranews.com/maranhao/rodovia-federal/', 'https://difusoranews.com/maranhao/banco-do-nordeste-cultural-inaugura-exposicao-nordeste-expandido-em-sao-luis/', 'https://difusoranews.com/maranhao/', 'https://difusoranews.com/maranhao/transporte-publico/onibus-estao-todos-velhos-diz-morador-da-regiao-itaqui-bacanga/', 'https://difusoranews.com/maranhao/transporte-publico/', 'https://difusoranews.com/economia/', 'https://difusoranews.com/economia/aneel-reduz-patamar-de-bandeira-vermelha-e-aumento-pode-ser-menor/', 'https://difusoranews.com/economia/lotomania-uma-aposta-em-sao-luis-faturou-o-premio-de-r73-mil/', 'https://difusoranews.com/economia/receita-federal-divulga-edital-do-leilao-eletronico-2024/', 'https://difusoranews.com/economia/aneel-aprova-reducao-na-tarifa-de-energia-eletrica-dos-consumidores-residenciais-do-maranhao/', 'https://difusoranews.com/economia/servicos/plataforma-tem-crescimento-de-100-em-hospedagem-com-pets/', 'https://difusoranews.com/eleicoes-2024/propaganda-eleitoral-em-postes-e-medidores-de-energia-e-proibida-saiba-como-denunciar/', 'https://difusoranews.com/policia/amigos-exibem-dinheiro-de-aposta-na-internet-e-sao-assaltados-em-caxias/', 'https://difusoranews.com/transito/motorista-morre-apos-carro-bater-em-muro-e-capotar-em-sao-luis/', 'https://difusoranews.com/maranhao/sao-luis/moradores-denunciam-descaso-e-abandono-no-mercado-da-forquilha/', 'https://difusoranews.com/maranhao/sao-luis/', 'https://difusoranews.com/maranhao/sao-luis/agenda-dos-candidatos-a-prefeitura-de-sao-luis-para-quinta-feira-12/', 'https://difusoranews.com/maranhao/radio-clandestina-e-fechada-pela-policia-federal-em-anapurus/', 'https://difusoranews.com/policia/adolescente-e-apreendido-por-envolvimento-em-roubo-a-moto-na-cohab/', 'https://difusoranews.com/eleicoes-2024/sabatina/candidato-eduardo-braide-falta-a-sabatina-do-grupo-difusora/', 'https://difusoranews.com/ao-vivo/', 'https://difusoranews.com/ao-vivo/imperatriz/', 'https://difusoranews.com/ao-vivo/caxias/', 'https://difusoranews.com/difusora-fm/', 'https://difusoranews.com/difusora-fm/imperatriz/', 'https://difusoranews.com/difusora-fm/caxias/', 'https://difusoranews.com/difusora-news-fm/', 'https://difusoranews.com/maranhao/maioria-dos-acidentes-de-transito-do-estado-envolve-motos-diz-senatran/', 'https://difusoranews.com/policia/video-homem-tenta-prestar-ajuda-e-e-roubado-em-sao-luis/', 'https://difusoranews.com/policia/seguranca-publi ...
# Acessando URL: https://difusoranews.com/page/3
# Links encontrados na página 3: ['https://difusoranews.com/eleicoes-2024/sabatina/saulo-arcangeli-defende-reducao-de-salario-e-criacao-de-empresa-de-onibus-da-prefeitura/', 'https://difusoranews.com/eleicoes-2024/sabatina/', 'https://difusoranews.com/eleicoes-2024/', 'https://difusoranews.com/eleicoes-2024/pesquisa-mostra-josinaldo-moraes-liderando-corrida-eleitoral-em-santa-helena/', 'https://difusoranews.com/oportunidade/', 'https://difusoranews.com/oportunidade/sextou-no-painel-de-emprego-com-vaga-para-fisioterapeuta/', 'https://difusoranews.com/eleicoes-2024/candidatos-a-prefeitura-de-sao-luis-divulgam-agenda-desta-sexta-feira-13/', 'https://difusoranews.com/esportes/rayssa-leal-garante-vaga-para-semifinal-do-mundial-de-skate-street-em-roma/', 'https://difusoranews.com/esportes/', 'https://difusoranews.com/eleicoes-2024/jhulio-sousa-lidera-disputa-pela-prefeitura-de-pocao-de-pedras-diz-pesquisa/', 'https://difusoranews.com/eleicoes-2024/nova-pesquisa-mostra-cenario-da-corrida-eleitoral-em-pinheiro/', 'https://difusoranews.com/transito/', 'https://difusoranews.com/transito/video-motociclista-tenta-ultrapassagem-bate-em-outra-moto-e-mata-mulher-na-raposa/', 'https://difusoranews.com/eleicoes-2024/pesquisa-aponta-cenario-da-disputa-pela-prefeitura-de-imperatriz/', 'https://difusoranews.com/policia/', 'https://difusoranews.com/policia/homem-disfarcado-de-policial-assalta-agencia-bancaria-em-pinheiro/', 'https://difusoranews.com/maranhao/rodovia-federal/motorista-provoca-engavetamento-na-br-010-apos-dirigir-por-24h-sem-parar/', 'https://difusoranews.com/maranhao/rodovia-federal/', 'https://difusoranews.com/maranhao/banco-do-nordeste-cultural-inaugura-exposicao-nordeste-expandido-em-sao-luis/', 'https://difusoranews.com/maranhao/', 'https://difusoranews.com/maranhao/transporte-publico/onibus-estao-todos-velhos-diz-morador-da-regiao-itaqui-bacanga/', 'https://difusoranews.com/maranhao/transporte-publico/', 'https://difusoranews.com/economia/', 'https://difusoranews.com/economia/aneel-reduz-patamar-de-bandeira-vermelha-e-aumento-pode-ser-menor/', 'https://difusoranews.com/economia/lotomania-uma-aposta-em-sao-luis-faturou-o-premio-de-r73-mil/', 'https://difusoranews.com/economia/receita-federal-divulga-edital-do-leilao-eletronico-2024/', 'https://difusoranews.com/economia/aneel-aprova-reducao-na-tarifa-de-energia-eletrica-dos-consumidores-residenciais-do-maranhao/', 'https://difusoranews.com/economia/servicos/plataforma-tem-crescimento-de-100-em-hospedagem-com-pets/', 'https://difusoranews.com/eleicoes-2024/propaganda-eleitoral-em-postes-e-medidores-de-energia-e-proibida-saiba-como-denunciar/', 'https://difusoranews.com/policia/amigos-exibem-dinheiro-de-aposta-na-internet-e-sao-assaltados-em-caxias/', 'https://difusoranews.com/transito/motorista-morre-apos-carro-bater-em-muro-e-capotar-em-sao-luis/', 'https://difusoranews.com/maranhao/sao-luis/moradores-denunciam-descaso-e-abandono-no-mercado-da-forquilha/', 'https://difusoranews.com/maranhao/sao-luis/', 'https://difusoranews.com/maranhao/sao-luis/agenda-dos-candidatos-a-prefeitura-de-sao-luis-para-quinta-feira-12/', 'https://difusoranews.com/maranhao/radio-clandestina-e-fechada-pela-policia-federal-em-anapurus/', 'https://difusoranews.com/policia/adolescente-e-apreendido-por-envolvimento-em-roubo-a-moto-na-cohab/', 'https://difusoranews.com/eleicoes-2024/sabatina/candidato-eduardo-braide-falta-a-sabatina-do-grupo-difusora/', 'https://difusoranews.com/ao-vivo/', 'https://difusoranews.com/ao-vivo/imperatriz/', 'https://difusoranews.com/ao-vivo/caxias/', 'https://difusoranews.com/difusora-fm/', 'https://difusoranews.com/difusora-fm/imperatriz/', 'https://difusoranews.com/difusora-fm/caxias/', 'https://difusoranews.com/difusora-news-fm/', 'https://difusoranews.com/maranhao/maioria-dos-acidentes-de-transito-do-estado-envolve-motos-diz-senatran/', 'https://difusoranews.com/policia/video-homem-tenta-prestar-ajuda-e-e-roubado-em-sao-luis/', 'https://difusoranews.com/policia/seguranca-publi ...
# Acessando URL: https://difusoranews.com/page/4
# Links encontrados na página 4: ['https://difusoranews.com/eleicoes-2024/sabatina/saulo-arcangeli-defende-reducao-de-salario-e-criacao-de-empresa-de-onibus-da-prefeitura/', 'https://difusoranews.com/eleicoes-2024/sabatina/', 'https://difusoranews.com/eleicoes-2024/', 'https://difusoranews.com/eleicoes-2024/pesquisa-mostra-josinaldo-moraes-liderando-corrida-eleitoral-em-santa-helena/', 'https://difusoranews.com/oportunidade/', 'https://difusoranews.com/oportunidade/sextou-no-painel-de-emprego-com-vaga-para-fisioterapeuta/', 'https://difusoranews.com/eleicoes-2024/candidatos-a-prefeitura-de-sao-luis-divulgam-agenda-desta-sexta-feira-13/', 'https://difusoranews.com/esportes/rayssa-leal-garante-vaga-para-semifinal-do-mundial-de-skate-street-em-roma/', 'https://difusoranews.com/esportes/', 'https://difusoranews.com/eleicoes-2024/jhulio-sousa-lidera-disputa-pela-prefeitura-de-pocao-de-pedras-diz-pesquisa/', 'https://difusoranews.com/eleicoes-2024/nova-pesquisa-mostra-cenario-da-corrida-eleitoral-em-pinheiro/', 'https://difusoranews.com/transito/', 'https://difusoranews.com/transito/video-motociclista-tenta-ultrapassagem-bate-em-outra-moto-e-mata-mulher-na-raposa/', 'https://difusoranews.com/eleicoes-2024/pesquisa-aponta-cenario-da-disputa-pela-prefeitura-de-imperatriz/', 'https://difusoranews.com/policia/', 'https://difusoranews.com/policia/homem-disfarcado-de-policial-assalta-agencia-bancaria-em-pinheiro/', 'https://difusoranews.com/maranhao/rodovia-federal/motorista-provoca-engavetamento-na-br-010-apos-dirigir-por-24h-sem-parar/', 'https://difusoranews.com/maranhao/rodovia-federal/', 'https://difusoranews.com/maranhao/banco-do-nordeste-cultural-inaugura-exposicao-nordeste-expandido-em-sao-luis/', 'https://difusoranews.com/maranhao/', 'https://difusoranews.com/maranhao/transporte-publico/onibus-estao-todos-velhos-diz-morador-da-regiao-itaqui-bacanga/', 'https://difusoranews.com/maranhao/transporte-publico/', 'https://difusoranews.com/economia/', 'https://difusoranews.com/economia/aneel-reduz-patamar-de-bandeira-vermelha-e-aumento-pode-ser-menor/', 'https://difusoranews.com/economia/lotomania-uma-aposta-em-sao-luis-faturou-o-premio-de-r73-mil/', 'https://difusoranews.com/economia/receita-federal-divulga-edital-do-leilao-eletronico-2024/', 'https://difusoranews.com/economia/aneel-aprova-reducao-na-tarifa-de-energia-eletrica-dos-consumidores-residenciais-do-maranhao/', 'https://difusoranews.com/economia/servicos/plataforma-tem-crescimento-de-100-em-hospedagem-com-pets/', 'https://difusoranews.com/eleicoes-2024/propaganda-eleitoral-em-postes-e-medidores-de-energia-e-proibida-saiba-como-denunciar/', 'https://difusoranews.com/policia/amigos-exibem-dinheiro-de-aposta-na-internet-e-sao-assaltados-em-caxias/', 'https://difusoranews.com/transito/motorista-morre-apos-carro-bater-em-muro-e-capotar-em-sao-luis/', 'https://difusoranews.com/maranhao/sao-luis/moradores-denunciam-descaso-e-abandono-no-mercado-da-forquilha/', 'https://difusoranews.com/maranhao/sao-luis/', 'https://difusoranews.com/maranhao/sao-luis/agenda-dos-candidatos-a-prefeitura-de-sao-luis-para-quinta-feira-12/', 'https://difusoranews.com/maranhao/radio-clandestina-e-fechada-pela-policia-federal-em-anapurus/', 'https://difusoranews.com/policia/adolescente-e-apreendido-por-envolvimento-em-roubo-a-moto-na-cohab/', 'https://difusoranews.com/eleicoes-2024/sabatina/candidato-eduardo-braide-falta-a-sabatina-do-grupo-difusora/', 'https://difusoranews.com/ao-vivo/', 'https://difusoranews.com/ao-vivo/imperatriz/', 'https://difusoranews.com/ao-vivo/caxias/', 'https://difusoranews.com/difusora-fm/', 'https://difusoranews.com/difusora-fm/imperatriz/', 'https://difusoranews.com/difusora-fm/caxias/', 'https://difusoranews.com/difusora-news-fm/', 'https://difusoranews.com/maranhao/maioria-dos-acidentes-de-transito-do-estado-envolve-motos-diz-senatran/', 'https://difusoranews.com/policia/video-homem-tenta-prestar-ajuda-e-e-roubado-em-sao-luis/', 'https://difusoranews.com/policia/seguranca-publi ...
# Acessando URL: https://difusoranews.com/page/5
# Links encontrados na página 5: ['https://difusoranews.com/eleicoes-2024/sabatina/saulo-arcangeli-defende-reducao-de-salario-e-criacao-de-empresa-de-onibus-da-prefeitura/', 'https://difusoranews.com/eleicoes-2024/sabatina/', 'https://difusoranews.com/eleicoes-2024/', 'https://difusoranews.com/eleicoes-2024/pesquisa-mostra-josinaldo-moraes-liderando-corrida-eleitoral-em-santa-helena/', 'https://difusoranews.com/oportunidade/', 'https://difusoranews.com/oportunidade/sextou-no-painel-de-emprego-com-vaga-para-fisioterapeuta/', 'https://difusoranews.com/eleicoes-2024/candidatos-a-prefeitura-de-sao-luis-divulgam-agenda-desta-sexta-feira-13/', 'https://difusoranews.com/esportes/rayssa-leal-garante-vaga-para-semifinal-do-mundial-de-skate-street-em-roma/', 'https://difusoranews.com/esportes/', 'https://difusoranews.com/eleicoes-2024/jhulio-sousa-lidera-disputa-pela-prefeitura-de-pocao-de-pedras-diz-pesquisa/', 'https://difusoranews.com/eleicoes-2024/nova-pesquisa-mostra-cenario-da-corrida-eleitoral-em-pinheiro/', 'https://difusoranews.com/transito/', 'https://difusoranews.com/transito/video-motociclista-tenta-ultrapassagem-bate-em-outra-moto-e-mata-mulher-na-raposa/', 'https://difusoranews.com/eleicoes-2024/pesquisa-aponta-cenario-da-disputa-pela-prefeitura-de-imperatriz/', 'https://difusoranews.com/policia/', 'https://difusoranews.com/policia/homem-disfarcado-de-policial-assalta-agencia-bancaria-em-pinheiro/', 'https://difusoranews.com/maranhao/rodovia-federal/motorista-provoca-engavetamento-na-br-010-apos-dirigir-por-24h-sem-parar/', 'https://difusoranews.com/maranhao/rodovia-federal/', 'https://difusoranews.com/maranhao/banco-do-nordeste-cultural-inaugura-exposicao-nordeste-expandido-em-sao-luis/', 'https://difusoranews.com/maranhao/', 'https://difusoranews.com/maranhao/transporte-publico/onibus-estao-todos-velhos-diz-morador-da-regiao-itaqui-bacanga/', 'https://difusoranews.com/maranhao/transporte-publico/', 'https://difusoranews.com/economia/', 'https://difusoranews.com/economia/aneel-reduz-patamar-de-bandeira-vermelha-e-aumento-pode-ser-menor/', 'https://difusoranews.com/economia/lotomania-uma-aposta-em-sao-luis-faturou-o-premio-de-r73-mil/', 'https://difusoranews.com/economia/receita-federal-divulga-edital-do-leilao-eletronico-2024/', 'https://difusoranews.com/economia/aneel-aprova-reducao-na-tarifa-de-energia-eletrica-dos-consumidores-residenciais-do-maranhao/', 'https://difusoranews.com/economia/servicos/plataforma-tem-crescimento-de-100-em-hospedagem-com-pets/', 'https://difusoranews.com/eleicoes-2024/propaganda-eleitoral-em-postes-e-medidores-de-energia-e-proibida-saiba-como-denunciar/', 'https://difusoranews.com/policia/amigos-exibem-dinheiro-de-aposta-na-internet-e-sao-assaltados-em-caxias/', 'https://difusoranews.com/transito/motorista-morre-apos-carro-bater-em-muro-e-capotar-em-sao-luis/', 'https://difusoranews.com/maranhao/sao-luis/moradores-denunciam-descaso-e-abandono-no-mercado-da-forquilha/', 'https://difusoranews.com/maranhao/sao-luis/', 'https://difusoranews.com/maranhao/sao-luis/agenda-dos-candidatos-a-prefeitura-de-sao-luis-para-quinta-feira-12/', 'https://difusoranews.com/maranhao/radio-clandestina-e-fechada-pela-policia-federal-em-anapurus/', 'https://difusoranews.com/policia/adolescente-e-apreendido-por-envolvimento-em-roubo-a-moto-na-cohab/', 'https://difusoranews.com/eleicoes-2024/sabatina/candidato-eduardo-braide-falta-a-sabatina-do-grupo-difusora/', 'https://difusoranews.com/ao-vivo/', 'https://difusoranews.com/ao-vivo/imperatriz/', 'https://difusoranews.com/ao-vivo/caxias/', 'https://difusoranews.com/difusora-fm/', 'https://difusoranews.com/difusora-fm/imperatriz/', 'https://difusoranews.com/difusora-fm/caxias/', 'https://difusoranews.com/difusora-news-fm/', 'https://difusoranews.com/maranhao/maioria-dos-acidentes-de-transito-do-estado-envolve-motos-diz-senatran/', 'https://difusoranews.com/policia/video-homem-tenta-prestar-ajuda-e-e-roubado-em-sao-luis/', 'https://difusoranews.com/policia/seguranca-publi ...
# Links de notícias extraídos e salvos em 'news_link.txt'.

# %% [markdown]
# ## Bibliotecas Utilizadas
# 1. **Requests**:
#    - Utilizamos a biblioteca `requests` para fazer as requisições HTTP e acessar as páginas do site. Essa biblioteca é simples e eficiente para recuperar o conteúdo HTML de qualquer página web.
#
# 2. **BeautifulSoup (bs4)**:
#    - Usamos o `BeautifulSoup` para realizar o parsing do HTML recuperado e facilitar a extração de dados das páginas. A partir dessa ferramenta, conseguimos utilizar seletores CSS e outras técnicas para localizar elementos do DOM, como links de notícias.
#
# ## Estratégia de Paginação
# - O site **Difusora News** não possuía um padrão claro de paginação. Portanto, fizemos um processo de tentativa e erro para descobrir o padrão correto. Após testes, confirmamos que o padrão correto para acessar páginas adicionais de notícias era o seguinte:
#    - `https://difusoranews.com/page/{numero_da_pagina}`
#
# - Esse padrão permitiu que acessássemos e raspássemos dados de várias páginas, de forma iterativa, usando um laço para cobrir as cinco primeiras páginas.
#
# ## Função de Verificação
# - Desenvolvemos uma função para comparar o HTML da página inicial com as páginas subsequentes. O objetivo era garantir que as páginas raspadas fossem de fato diferentes da página inicial, evitando duplicações e resultados inválidos.
#
# ## Armazenamento de Links
# - Após coletar os links de cada página, salvamos esses links em um arquivo `news_links.txt`. Esse processo é fundamental para estruturar e organizar os dados extraídos de forma a permitir futuros processamentos e análises.
#
# ## Aplicação Prática
# Essa estratégia de **web scraping** é valiosa para automação de coleta de dados em larga escala. Por exemplo, no contexto de monitoramento de notícias (como o nosso caso), a empresa poderia automatizar o acompanhamento de notícias específicas, extraindo informações relevantes (títulos, links, textos) para análise de mídia, sentimento ou tendências de mercado.

# %% [markdown]
# **Exercício 9:**
#
# Repita a questão anterior utilizando um site de notícias de sua escolh

# %%
import requests
from bs4 import BeautifulSoup

# URL do site de notícias escolhido (CNN Brasil)
base_url = "https://www.cnnbrasil.com.br/"

# Padrões de paginação para teste
pagination_patterns = [
    "https://www.cnnbrasil.com.br/page/{}",       # Padrão 1
    "https://www.cnnbrasil.com.br/?pagina={}",    # Padrão 2
    "https://www.cnnbrasil.com.br/noticias/page/{}", # Padrão 3
    "https://www.cnnbrasil.com.br/?pg={}",        # Padrão 4
]

# Função para verificar se a página atual é diferente da inicial
def is_valid_pagination(soup_initial, soup_page):
    return soup_initial != soup_page

# Obter conteúdo da página inicial
response_initial = requests.get(base_url)
soup_initial = BeautifulSoup(response_initial.content, "html.parser")

# Lista para armazenar os links de notícias
news_links = []

# Loop para testar padrões de paginação
for pattern in pagination_patterns:
    for page_num in range(1, 6):  # Testando as 5 primeiras páginas
        url = pattern.format(page_num)
        print(f"Acessando URL: {url}")
        response = requests.get(url)

        if response.status_code == 200:
            soup_page = BeautifulSoup(response.content, "html.parser")

            # Verifica se a página atual é diferente da inicial
            if is_valid_pagination(soup_initial, soup_page):
                # Extração dos links de notícias
                for link in soup_page.select("a[href]"):  # Seleciona todos os links <a>
                    href = link.get("href")
                    if href and "cnnbrasil.com.br" in href:
                        news_links.append(href)
                print(f"Links encontrados na página {page_num}.")
            else:
                print(f"A página {page_num} parece ser igual à página inicial.")
        else:
            print(f"Erro ao acessar {url}: Status {response.status_code}")

# Salvando os links em um arquivo .txt
with open("cnn_news_links.txt", "w") as f:
    for link in news_links:
        f.write(f"{link}\n")

print("Links de notícias extraídos e salvos em 'cnn_news_links.txt'.")
# Out:
# Acessando URL: https://www.cnnbrasil.com.br/page/1
# Erro ao acessar https://www.cnnbrasil.com.br/page/1: Status 404
# Acessando URL: https://www.cnnbrasil.com.br/page/2
# Erro ao acessar https://www.cnnbrasil.com.br/page/2: Status 404
# Acessando URL: https://www.cnnbrasil.com.br/page/3
# Erro ao acessar https://www.cnnbrasil.com.br/page/3: Status 404
# Acessando URL: https://www.cnnbrasil.com.br/page/4
# Erro ao acessar https://www.cnnbrasil.com.br/page/4: Status 404
# Acessando URL: https://www.cnnbrasil.com.br/page/5
# Erro ao acessar https://www.cnnbrasil.com.br/page/5: Status 404
# Acessando URL: https://www.cnnbrasil.com.br/?pagina=1
# Links encontrados na página 1.
# Acessando URL: https://www.cnnbrasil.com.br/?pagina=2
# Links encontrados na página 2.
# Acessando URL: https://www.cnnbrasil.com.br/?pagina=3
# Links encontrados na página 3.
# Acessando URL: https://www.cnnbrasil.com.br/?pagina=4
# Links encontrados na página 4.
# Acessando URL: https://www.cnnbrasil.com.br/?pagina=5
# Links encontrados na página 5.
# Acessando URL: https://www.cnnbrasil.com.br/noticias/page/1
# Links encontrados na página 1.
# Acessando URL: https://www.cnnbrasil.com.br/noticias/page/2
# Links encontrados na página 2.
# Acessando URL: https://www.cnnbrasil.com.br/noticias/page/3
# Links encontrados na página 3.
# Acessando URL: https://www.cnnbrasil.com.br/noticias/page/4
# Links encontrados na página 4.
# Acessando URL: https://www.cnnbrasil.com.br/noticias/page/5
# Links encontrados na página 5.
# Acessando URL: https://www.cnnbrasil.com.br/?pg=1
# Links encontrados na página 1.
# Acessando URL: https://www.cnnbrasil.com.br/?pg=2
# Links encontrados na página 2.
# Acessando URL: https://www.cnnbrasil.com.br/?pg=3
# Links encontrados na página 3.
# Acessando URL: https://www.cnnbrasil.com.br/?pg=4
# Links encontrados na página 4.
# Acessando URL: https://www.cnnbrasil.com.br/?pg=5
# Links encontrados na página 5.
# Links de notícias extraídos e salvos em 'cnn_news_links.txt'.

# %% [markdown]
# ## Exercício 10:
#
# Consulte o arquivo `robots.txt` do site https://tecnoblog.net/ para encontrar o link do `sitemap_index` e obtenha a partir dele a lista de todos os sitemaps de notícias (filtrando apenas os de notícias).

# %%
import requests
from bs4 import BeautifulSoup

# Definir o URL do sitemap
sitemap_url = "https://tecnoblog.net/sitemap_index.xml"

# Headers para simular um navegador
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
}

# Fazer a requisição para o sitemap_index.xml
response = requests.get(sitemap_url, headers=headers)

if response.status_code == 200:
    # Parser do conteúdo XML
    soup = BeautifulSoup(response.content, 'xml')
    
    # Extrair todos os sitemaps
    sitemaps = soup.find_all('sitemap')
    
    # Filtrar e imprimir apenas os sitemaps de notícias
    for sitemap in sitemaps:
        loc = sitemap.find('loc').text
        if "noticia" in loc or "news" in loc:
            print(f"Sitemap de notícias encontrado: {loc}")
            
            # Fazer requisição para cada sitemap de notícias
            news_sitemap_response = requests.get(loc, headers=headers)
            if news_sitemap_response.status_code == 200:
                news_soup = BeautifulSoup(news_sitemap_response.content, 'xml')
                news_links = news_soup.find_all('url')
                
                # Extrair e mostrar os links das notícias
                for news in news_links:
                    news_url = news.find('loc').text
                    print(f"Notícia encontrada: {news_url}")
else:
    print(f"Erro ao acessar o sitemap. Status code: {response.status_code}")
# Out:
# Sitemap de notícias encontrado: https://tecnoblog.net/noticias-sitemap.xml
# Notícia encontrada: https://tecnoblog.net/noticias/
# Notícia encontrada: https://tecnoblog.net/noticias/mercado-livre-vai-mudar-taxa-de-frete-gratis-e-subsidio-para-vendedores/
# Notícia encontrada: https://tecnoblog.net/noticias/nova-operadora-devera-levar-sinal-em-4g-para-36-mil-km-de-estradas/
# Notícia encontrada: https://tecnoblog.net/noticias/game-of-thrones-e-friends-dominam-retrospectiva-2021-da-hbo-max-no-brasil/
# Notícia encontrada: https://tecnoblog.net/noticias/celular-simples-da-samsung-galaxy-a03-core-e-homologado-pela-anatel/
# Notícia encontrada: https://tecnoblog.net/noticias/pubg-new-state-e-lancado-para-android-e-iphone-mas-trava-celulares/
# Notícia encontrada: https://tecnoblog.net/noticias/loggi-monta-megagalpao-em-sp-para-processar-ate-1-milhao-de-pacotes-por-dia/
# Notícia encontrada: https://tecnoblog.net/noticias/smartphone-e-campeao-de-queixas-sobre-blackfriday-no-reclame-aqui/
# Notícia encontrada: https://tecnoblog.net/noticias/ministerio-da-saude-tem-backup-de-dados-diz-queiroga-apos-ataque-hacker/
# Notícia encontrada: https://tecnoblog.net/noticias/nubank-estreia-na-b3-com-bdrs-valendo-quase-r-11-e-acao-com-alta-de-7/
# Notícia encontrada: https://tecnoblog.net/noticias/whatsapp-beta-ganha-opcao-para-ocultar-visto-por-ultimo-de-algumas-pessoas/
# Notícia encontrada: https://tecnoblog.net/noticias/moto-g71-com-camera-tripla-e-bateria-de-4-700-mah-e-certificado/
# Notícia encontrada: https://tecnoblog.net/noticias/sindicato-do-porto-de-santos-marca-protesto-contra-amazon-na-black-friday/
# Notícia encontrada: https://tecnoblog.net/noticias/paramount-volta-atras-e-adianta-estreia-de-novo-star-trek-no-brasil/
# Notícia encontrada: https://tecnoblog.net/noticias/lg-oferece-notebook-a-biologo-brasileiro-que-ganhou-celular-da-xiaomi/
# Notícia encontrada: https://tecnoblog.net/noticias/instagram-e-facebook-lancam-recursos-para-voce-criar-sua-retrospectiva-2021/
# Notícia encontrada: https://tecnoblog.net/noticias/exclusivo-ministerio-publico-quer-r-19-milhao-de-site-que-baixa-videos-do-youtube/
# Notícia encontrada: https://tecnoblog.net/noticias/conectesus-nao-exibe-vacinas-apos-ataque-hacker-ao-ministerio-da-saude/
# Notícia encontrada: https://tecnoblog.net/noticias/tectoy-anuncia-novo-console-legends-core-com-100-jogos-na-memoria/
# Notícia encontrada: https://tecnoblog.net/noticias/chefe-do-instagram-vai-depor-nos-eua-sobre-efeitos-nocivos-do-app-em-jovens/
# Notícia encontrada: https://tecnoblog.net/noticias/roblox-bane-e-processa-youtuber-em-us-16-milhao-por-ameaca-terrorista/
# Notícia encontrada: https://tecnoblog.net/noticias/pubg-sera-gratis-para-jogar-a-partir-de-2022-e-tera-novo-battlegrounds-plus/
# Notícia encontrada: https://tecnoblog.net/noticias/avell-tem-notebooks-b-on-e-mob-com-descontos-de-ate-r-4-mil-em-novembro/
# Notícia encontrada: https://tecnoblog.net/noticias/mulher-e-condenada-por-tentar-contratar-assassino-de-aluguel-pela-internet/
# Notícia encontrada: https://tecnoblog.net/noticias/lenovo-legion-slim-7-notebook-gamer-mais-fino-da-empresa-chega-ao-brasil/
# Notícia encontrada: https://tecnoblog.net/noticias/redmi-note-11-4g-e-o-xiaomi-redmi-10-com-uma-camera-a-menos/
# Notícia encontrada: https://tecnoblog.net/noticias/final-fantasy-7-remake-para-pc-chega-a-epic-games-store-ainda-em-2021/
# Notícia encontrada: https://tecnoblog.net/noticias/sonic-frontiers-chega-em-2022-e-segundo-filme-ganha-trailer/
# Notícia encontrada: https://tecnoblog.net/noticias/whatsapp-beta-libera-mensagens-que-desaparecem-em-24-horas-ou-3-meses/
# Notícia encontrada: https://tecnoblog.net/noticias/projeto-de-lei-quer-combater-efeito-bolha-do-instagram-youtube-e-mais/
# Notícia encontrada: https://tecnoblog.net/noticias/iphone-13-pressionada-apple-cede-e-remove-dificuldade-para-troca-de-tela/
# Notícia encontrada: https://tecnoblog.net/noticias/the-game-awards-2021-veja-alguns-destaques-do-pre-show/
# Notícia encontrada: https://tecnoblog.net/noticias/galaxy-s22-deve-chegar-ao-brasil-com-processador-da-samsung-e-graficos-amd/
# Notícia encontrada: https://tecnoblog.net/noticias/governo-vai-adicionar-biometria-da-pf-a-base-gov-br-para-identificar-cidadaos/
# Notícia encontrada: https://tecnoblog.net/noticias/zte-axon-30-ultra-ganha-nova-edicao-com-18-gb-de-ram-e-1-tb-de-espaco/
# Notícia encontrada: https://tecnoblog.net/noticias/redmi-10-2022-e-certificado-e-deve-ser-lancado-com-camera-de-50-mp/
# Notícia encontrada: https://tecnoblog.net/noticias/alan-wake-2-chega-em-2023-como-um-jogo-de-terror-e-sobrevivencia/
# Notícia encontrada: https://tecnoblog.net/noticias/the-game-awards-2021-conheca-o-goty-e-todos-os-vencedores-do-evento/
# Notícia encontrada: https://tecnoblog.net/noticias/sites-de-games-piratas-sao-alvos-da-policia-civil-de-sp-em-operacao-brick/
# Notícia encontrada: https://tecnoblog.net/noticias/multilaser-mira-em-pais-e-filhos-com-tablet-m8-e-modelo-patrulha-canina/
# Notícia encontrada: https://tecnoblog.net/noticias/americanas-ponto-e-outras-fecham-cerco-e-combatem-produtos-sem-selo-anatel/
# Notícia encontrada: https://tecnoblog.net/noticias/pagamento-por-qr-code-sera-aceito-em-600-onibus-da-cidade-de-sao-paulo/
# Notícia encontrada: https://tecnoblog.net/noticias/netflix-se-inspira-no-tiktok-com-videos-curtos-para-distrair-criancas/
# Notícia encontrada: https://tecnoblog.net/noticias/mpt-defende-vinculo-empregaticio-de-motoristas-com-99-uber-e-rappi/
# Notícia encontrada: https://tecnoblog.net/noticias/google-processa-russos-que-usaram-blockchain-para-infectar-milhares-de-pcs/
# Notícia encontrada: https://tecnoblog.net/noticias/oi-inicia-vendas-de-internet-fibra-optica-em-guarulhos-apos-chegada-em-sp/
# Notícia encontrada: https://tecnoblog.net/noticias/gta-trilogy-remastered-tem-video-com-meia-hora-de-gameplay-publicado/
# Notícia encontrada: https://tecnoblog.net/noticias/fairphone-2-lancado-ha-anos-com-android-5-0-inicia-testes-do-android-10/
# Notícia encontrada: https://tecnoblog.net/noticias/allugator-abre-lote-para-investir-em-iphone-13-prometendo-ate-300-do-cdi/
# Notícia encontrada: https://tecnoblog.net/noticias/cod-warzone-pacific-estreia-com-mapa-caldera-e-novos-modos-de-jogo/
# Notícia encontrada: https://tecnoblog.net/noticias/jump-force-bandai-namco-desiste-de-jogo-de-luta-e-detalha-mudancas-para-2022/
# Notícia encontrada: https://tecnoblog.net/noticias/xiaomi-12-pode-trazer-recarga-rapida-de-100-w-e-downgrade-na-tela/
# Notícia encontrada: https://tecnoblog.net/noticias/android-12l-com-melhorias-para-telas-maiores-ganha-primeiro-beta/
# Notícia encontrada: https://tecnoblog.net/noticias/este-jogo-do-pinoquio-quer-ser-um-novo-bloodborne/
# Notícia encontrada: https://tecnoblog.net/noticias/samsung-provoca-pano-de-r-219-da-apple-ao-oferecer-acessorio-de-graca/
# Notícia encontrada: https://tecnoblog.net/noticias/cartucho-permite-que-game-boy-advance-rode-jogos-de-playstation/
# Notícia encontrada: https://tecnoblog.net/noticias/assassins-creed-valhalla-devera-ser-reinstalado-na-proxima-atualizacao/
# Notícia encontrada: https://tecnoblog.net/noticias/winamp-classico-player-de-musica-abre-cadastro-para-testar-nova-versao/
# Notícia encontrada: https://tecnoblog.net/noticias/galaxy-s22-e-s22-ficam-mais-proximos-de-lancamento-apos-homologacao-nos-eua/
# Notícia encontrada: https://tecnoblog.net/noticias/golpe-via-whatsapp-usa-dados-vazados-e-pede-dinheiro-a-parentes-da-vitima/
# Notícia encontrada: https://tecnoblog.net/noticias/gaviao-arqueiro-estreia-no-disney-com-eventos-pos-vingadores-ultimato/
# Notícia encontrada: https://tecnoblog.net/noticias/whatsapp-agora-deixa-mais-usuarios-criarem-stickers-mas-so-no-pc/
# Notícia encontrada: https://tecnoblog.net/noticias/pix-e-usado-por-49-dos-brasileiros-mas-so-35-preferem-ferramenta-do-bc/
# Notícia encontrada: https://tecnoblog.net/noticias/galaxy-s21-fe-esta-demorando-tanto-que-deve-vir-com-android-12/
# Notícia encontrada: https://tecnoblog.net/noticias/novo-porteiro-eletronico-da-intelbras-com-biometria-facial-passa-na-anatel/
# Notícia encontrada: https://tecnoblog.net/noticias/instagram-prepara-retorno-do-feed-cronologico-diz-chefe-da-rede-social/
# Notícia encontrada: https://tecnoblog.net/noticias/justica-manda-sony-reativar-ps5-banido-mas-diz-que-conduta-nao-foi-ilicita/
# Notícia encontrada: https://tecnoblog.net/noticias/pl-das-fake-news-e-aprovado-sem-definir-limites-para-telegram-e-whatsapp/
# Notícia encontrada: https://tecnoblog.net/noticias/anatel-e-obrigada-a-desmentir-fake-news-sobre-5g-e-morte-de-passaros/
# Notícia encontrada: https://tecnoblog.net/noticias/estudio-brasileiro-lanca-app-de-criacao-de-mapas-para-rpg-com-ia/
# Notícia encontrada: https://tecnoblog.net/noticias/tim-ve-dificuldades-em-5g-ilimitado-e-quer-usar-frequencias-do-leilao-no-4g/
# Notícia encontrada: https://tecnoblog.net/noticias/sem-snapdragon-898-qualcomm-muda-nomes-e-deve-lancar-snapdragon-8-gen-1/
# Notícia encontrada: https://tecnoblog.net/noticias/novo-splinter-cell-pode-ser-mais-um-jogo-em-mundo-aberto-da-ubisoft/
# Notícia encontrada: https://tecnoblog.net/noticias/pl-da-privatizacao-dos-correios-pode-ser-barrado-em-comissao-do-senado/
# Notícia encontrada: https://tecnoblog.net/noticias/positivo-tab-q8-e-lancado-com-tela-de-8-polegadas-e-android-11-go/
# Notícia encontrada: https://tecnoblog.net/noticias/microsoft-lanca-museu-do-xbox-com-historico-de-jogos-e-consoles-do-usuario/
# Notícia encontrada: https://tecnoblog.net/noticias/google-tradutor-e-usado-por-turistas-franceses-para-entender-briga-no-rio/
# Notícia encontrada: https://tecnoblog.net/noticias/youtube-vai-ser-mantido-no-roku-apos-acordo-com-google/
# Notícia encontrada: https://tecnoblog.net/noticias/um-ano-depois-android-11-ainda-nao-e-a-versao-mais-usada-em-dispositivos/
# Notícia encontrada: https://tecnoblog.net/noticias/xiaomi-lanca-poco-m4-pro-5g-com-camera-de-50-mp-e-bateria-grande/
# Notícia encontrada: https://tecnoblog.net/noticias/nubank-ganha-shopping-dentro-do-aplicativo-com-cupons-e-descontos/
# Notícia encontrada: https://tecnoblog.net/noticias/fortnite-agora-e-desenvolvido-na-unreal-engine-5-mas-o-que-isso-significa/
# Notícia encontrada: https://tecnoblog.net/noticias/menos-uma-operadora-fly-link-desiste-de-5g-apos-arrematar-lote-em-leilao/
# Notícia encontrada: https://tecnoblog.net/noticias/biologo-brasileiro-ganha-celular-novo-da-xiaomi-apos-pedir-ajuda-a-samsung/
# Notícia encontrada: https://tecnoblog.net/noticias/producao-do-iphone-13-chegou-a-ser-suspensa-por-falta-de-chips/
# Notícia encontrada: https://tecnoblog.net/noticias/gta-5-finalmente-vai-receber-conteudo-de-historia-para-um-jogador/
# Notícia encontrada: https://tecnoblog.net/noticias/mpf-vai-investigar-politicas-do-whatsapp-e-telegram-para-combater-fake-news/
# Notícia encontrada: https://tecnoblog.net/noticias/ame-go-americanas-vai-abrir-a-sua-primeira-loja-autonoma-no-rio-de-janeiro/
# Notícia encontrada: https://tecnoblog.net/noticias/pcs-com-windows-11-e-processador-da-samsung-podem-desafiar-intel-em-breve/
# Notícia encontrada: https://tecnoblog.net/noticias/uniao-e-condenada-por-omissao-em-processo-do-mpf-contra-microsoft/
# Notícia encontrada: https://tecnoblog.net/noticias/instagram-volta-atras-e-remove-tag-de-fake-news-em-post-de-carlos-bolsonaro/
# Notícia encontrada: https://tecnoblog.net/noticias/piano-de-papel-usa-tinta-condutiva-celular-e-nfc-para-produzir-som/
# Notícia encontrada: https://tecnoblog.net/noticias/niantic-entra-no-metaverso-com-app-que-cria-objetos-virtuais-no-mundo-real/
# Notícia encontrada: https://tecnoblog.net/noticias/ps5-ganha-controle-no-estilo-do-xbox-elite-com-recursos-do-dualsense/
# Notícia encontrada: https://tecnoblog.net/noticias/clientes-do-banco-inter-reclamam-de-erro-em-promocao-que-dava-cartao-black/
# Notícia encontrada: https://tecnoblog.net/noticias/procon-sp-quer-barrar-app-de-compras-facily-recordista-em-reclamacoes/
# Notícia encontrada: https://tecnoblog.net/noticias/lg-lanca-fones-tone-free-fp5-e-fp9-com-anc-e-tecnologia-autolimpante-no-brasil/
# Notícia encontrada: https://tecnoblog.net/noticias/adele-pede-e-spotify-remove-reproducao-aleatoria-de-albuns-por-padrao/
# Notícia encontrada: https://tecnoblog.net/noticias/youtube-apaga-video-em-que-bolsonaro-questiona-pressa-da-vacina/
# Notícia encontrada: https://tecnoblog.net/noticias/anatel-exige-ativacao-do-radio-fm-em-celulares-compativeis-com-a-tecnologia/
# Notícia encontrada: https://tecnoblog.net/noticias/galaxy-s22-ultra-deve-ser-novo-note-fotos-vazadas-mostram-espaco-para-s-pen/
# Notícia encontrada: https://tecnoblog.net/noticias/banco-central-muda-faixa-horario-periodo-noturno-transfererencias-pix/
# Notícia encontrada: https://tecnoblog.net/noticias/ps5-colorido-sony-registra-patente-de-placas-laterais-para-o-console/
# Notícia encontrada: https://tecnoblog.net/noticias/inter-arcade-e-a-assinatura-do-banco-inter-com-mais-de-1-mil-games-mobile/
# Notícia encontrada: https://tecnoblog.net/noticias/instagram-sinaliza-fake-news-em-post-de-carlos-bolsonaro-sobre-lula/
# Notícia encontrada: https://tecnoblog.net/noticias/tomb-raider-e-mais-jogos-de-pc-quebram-apos-dominio-antipirataria-expirar/
# Notícia encontrada: https://tecnoblog.net/noticias/venom-branco-personagem-de-street-fighter-3-vira-trend-no-tiktok/
# Notícia encontrada: https://tecnoblog.net/noticias/windows-11-tem-derrubado-o-desempenho-de-alguns-ssds-nvme/
# Notícia encontrada: https://tecnoblog.net/noticias/xiaomi-12-e-homologado-celular-pode-ter-snapdragon-898-e-recarga-de-100-w/
# Notícia encontrada: https://tecnoblog.net/noticias/whatsapp-web-enfim-deixara-voce-ajustar-o-visto-por-ultimo-atraves-do-pc/
# Notícia encontrada: https://tecnoblog.net/noticias/instagram-e-facebook-adiam-plano-de-criptografar-mensagens-como-no-whatsapp/
# Notícia encontrada: https://tecnoblog.net/noticias/facily-reembolsa-clientes-apos-bater-recorde-de-queixas-no-procon-sp/
# Notícia encontrada: https://tecnoblog.net/noticias/sony-anuncia-detalhes-do-relancamento-de-uncharted-4-no-ps5-e-pc/
# Notícia encontrada: https://tecnoblog.net/noticias/fundador-da-safernet-brasil-cita-ameacas-de-morte-e-deixa-o-pais/
# Notícia encontrada: https://tecnoblog.net/noticias/vivo-easy-ficou-mais-caro-precos-de-diarias-de-apps-e-voz-sobem-ate-100/
# Notícia encontrada: https://tecnoblog.net/noticias/xiaomi-abre-a-segunda-loja-oficial-no-rio-de-janeiro/
# Notícia encontrada: https://tecnoblog.net/noticias/metal-gear-solid-tem-versoes-digitais-removidas-de-lojas-online/
# Notícia encontrada: https://tecnoblog.net/noticias/disney-tera-13-filmes-da-marvel-na-proporcao-imax-com-barras-pretas-menores/
# Notícia encontrada: https://tecnoblog.net/noticias/inscryption-e-loop-hero-sao-roguelikes-de-cartas-inovadores-e-divertidos/
# Notícia encontrada: https://tecnoblog.net/noticias/moto-g200-5g-chega-ao-brasil-com-snapdragon-888-e-tela-de-144-hz/
# Notícia encontrada: https://tecnoblog.net/noticias/moto-g71-5g-e-moto-g31-sao-anunciados-no-brasil-com-oled-e-camera-de-50-mp/
# Notícia encontrada: https://tecnoblog.net/noticias/netflix-deve-encarar-regras-rigidas-da-apple-para-levar-jogos-ao-iphone/
# Notícia encontrada: https://tecnoblog.net/noticias/bandai-namco-detalha-como-elden-ring-vai-ser-bonito-na-nova-geracao/
# Notícia encontrada: https://tecnoblog.net/noticias/microsoft-promete-melhorar-desempenho-interface-windows-11/
# Notícia encontrada: https://tecnoblog.net/noticias/whatsapp-agora-permite-criar-chats-que-somem-em-24-horas-ou-mais-por-padrao/
# Notícia encontrada: https://tecnoblog.net/noticias/comunidades-do-whatsapp-devem-trazer-melhorias-para-administrar-grupos/
# Notícia encontrada: https://tecnoblog.net/noticias/witch-n-wiz-e-um-jogo-de-nes-que-sera-lancado-em-cartucho/
# Notícia encontrada: https://tecnoblog.net/noticias/apos-piramides-de-bitcoin-projeto-de-lei-cobra-regras-para-corretoras-no-rj/
# Notícia encontrada: https://tecnoblog.net/noticias/bolsonaristas-usam-telegram-para-impulsionar-videos-ocultados-no-youtube/
# Notícia encontrada: https://tecnoblog.net/noticias/funcionarios-da-activision-protestam-contra-demissoes-em-estudio-de-cod/
# Notícia encontrada: https://tecnoblog.net/noticias/rockstar-se-desculpa-por-fiasco-de-gta-trilogy-e-promete-updates-no-futuro/
# Notícia encontrada: https://tecnoblog.net/noticias/amd-mediatek-parceria-modulos-wi-fi-6e-notebooks-desktops/
# Notícia encontrada: https://tecnoblog.net/noticias/trote-stf-determina-que-estados-podem-exigir-dados-de-quem-engana-o-190/
# Notícia encontrada: https://tecnoblog.net/noticias/riocard-mais-ganha-programa-de-pontos-que-podem-render-passagem-gratis-no-rj/
# Notícia encontrada: https://tecnoblog.net/noticias/the-matrix-awakens-e-demo-tecnologica-do-ps5-e-xbox-series-xs/
# Notícia encontrada: https://tecnoblog.net/noticias/spiritfarer-vai-ter-mais-conteudo-gratis-mesmo-depois-de-um-ano/
# Notícia encontrada: https://tecnoblog.net/noticias/steel-assault-se-inspira-em-jogos-retro-com-muita-acao-e-dificuldade-alta/
# Notícia encontrada: https://tecnoblog.net/noticias/funimation-e-crunchyroll-anunciam-exibicao-do-final-de-attack-on-titan/
# Notícia encontrada: https://tecnoblog.net/noticias/uber-tem-prejuizo-de-us-24-bilhoes-e-promete-retorno-do-uber-juntos/
# Notícia encontrada: https://tecnoblog.net/noticias/buddypoke-e-voce-tinder-planeja-encontro-de-avatares-no-metaverso/
# Notícia encontrada: https://tecnoblog.net/noticias/positivo-lanca-notebook-motion-c4120f-ax-com-botao-alexa-e-windows-11/
# Notícia encontrada: https://tecnoblog.net/noticias/xiaomi-redmi-k50-deve-chegar-em-4-versoes-uma-delas-com-snapdragon-8-gen-1/
# Notícia encontrada: https://tecnoblog.net/noticias/compre-compre-compre-mercado-livre-lanca-canal-shoptime-com-lives/
# Notícia encontrada: https://tecnoblog.net/noticias/acer-aspire-vero-no-brasil-notebook-traz-ssd-windows-11-e-plastico-reciclado/
# Notícia encontrada: https://tecnoblog.net/noticias/viu-e-um-app-que-mostra-quando-ha-tiroteios-e-arrastoes-no-rio-de-janeiro/
# Notícia encontrada: https://tecnoblog.net/noticias/google-assistente-ganha-vozes-vermelho-e-laranja-contra-rotulos-de-genero/
# Notícia encontrada: https://tecnoblog.net/noticias/forza-horizon-5-e-o-jogo-com-maior-nota-em-2021-e-zero-reviews-negativos/
# Notícia encontrada: https://tecnoblog.net/noticias/via-inaugura-megaloja-da-casas-bahia-com-gurus-tech-e-robo-concierge/
# Notícia encontrada: https://tecnoblog.net/noticias/macbook-pro-com-apple-m1-pro-e-max-chega-ao-brasil-por-ate-r-78-mil/
# Notícia encontrada: https://tecnoblog.net/noticias/xiaomi-12x-pode-ser-lancado-com-tela-menor-de-120-hz-e-snapdragon-870/
# Notícia encontrada: https://tecnoblog.net/noticias/motorola-edge-x30-pode-ser-lancado-com-android-12-e-camera-de-50-mp/
# Notícia encontrada: https://tecnoblog.net/noticias/microsoft-azure-10-supercomputador-mais-rapido-mundo-linux/
# Notícia encontrada: https://tecnoblog.net/noticias/fortnite-muda-tudo-e-traz-homem-aranha-com-the-rock-no-capitulo-3/
# Notícia encontrada: https://tecnoblog.net/noticias/xiaomi-12-lite-pode-ser-um-celular-intermediario-com-camera-tripla/
# Notícia encontrada: https://tecnoblog.net/noticias/mario-kart-home-ganha-atualizacao-com-multiplayer-no-switch/
# Notícia encontrada: https://tecnoblog.net/noticias/iphone-13-requer-transplante-de-chip-para-trocar-tela-sem-pagar-a-apple/
# Notícia encontrada: https://tecnoblog.net/noticias/aparelho-usado-pelo-fbi-ganha-nova-funcao-driblar-vigilancia-no-home-office/
# Notícia encontrada: https://tecnoblog.net/noticias/chefe-do-xbox-repensa-parceria-com-activision-blizzard-apos-novo-escandalo/
# Notícia encontrada: https://tecnoblog.net/noticias/os-15-melhores-apps-e-jogos-para-iphone-e-ipad-em-2021-segundo-a-apple/
# Notícia encontrada: https://tecnoblog.net/noticias/claro-tim-e-vivo-terao-5g-mais-rapido-e-mais-raro-de-ondas-milimetricas/
# Notícia encontrada: https://tecnoblog.net/noticias/criaram-um-the-pirate-bay-com-todos-os-nfts-da-ethereum-e-solana/
# Notícia encontrada: https://tecnoblog.net/noticias/windows-11-microsoft-ouve-criticas-e-facilita-escolha-de-navegador-padrao/
# Notícia encontrada: https://tecnoblog.net/noticias/whatsapp-libera-uso-em-outros-aparelhos-sem-celular-conectado/
# Notícia encontrada: https://tecnoblog.net/noticias/motorola-rokr-500-e-uma-caixa-de-som-bluetooth-com-carregador-sem-fio/
# Notícia encontrada: https://tecnoblog.net/noticias/xiaomi-revela-como-vai-esfriar-celulares-usando-tecnologia-loop-liquidcool/
# Notícia encontrada: https://tecnoblog.net/noticias/eua-oferecem-10-milhes-dolares-informacoes-ransomware-darkside/
# Notícia encontrada: https://tecnoblog.net/noticias/phil-spencer-defende-emulacao-como-forma-de-preservar-jogos/
# Notícia encontrada: https://tecnoblog.net/noticias/sony-deve-lancar-game-pass-proprio-com-jogos-do-ps1-ao-ps5/
# Notícia encontrada: https://tecnoblog.net/noticias/xiaomi-miui-segue-samsung-e-adiciona-barra-lateral-com-atalhos-para-apps/
# Notícia encontrada: https://tecnoblog.net/noticias/xbox-360-iphone-7-e-notebooks-dell-lideram-vendas-na-olx/
# Notícia encontrada: https://tecnoblog.net/noticias/policia-civil-rio-de-janeiro-empresa-pagava-traficantes-monopolio-internet/
# Notícia encontrada: https://tecnoblog.net/noticias/nubank-tem-instabilidade-nesta-sexta-feira-3-que-dificulta-acesso-ao-app/
# Notícia encontrada: https://tecnoblog.net/noticias/nao-gosta-de-academia-jogos-interativos-ajudam-no-combate-ao-sedentarismo/
# Notícia encontrada: https://tecnoblog.net/noticias/caixa-tem-nao-permite-ajustar-limite-do-pix-o-que-pode-violar-norma-do-bc/
# Notícia encontrada: https://tecnoblog.net/noticias/xbox-melhora-controle-latencia-e-inclui-tags-de-acessibilidade-em-update/
# Notícia encontrada: https://tecnoblog.net/noticias/it-takes-two-pode-mudar-de-nome-apos-acao-legal-da-empresa-de-gta/
# Notícia encontrada: https://tecnoblog.net/noticias/iphone-x-com-porta-usb-c-esta-em-leilao-e-ja-passou-dos-r-500-mil/
# Notícia encontrada: https://tecnoblog.net/noticias/moto-g71-5g-g51-e-mais-confira-a-avalanche-de-novos-celulares-da-motorola/
# Notícia encontrada: https://tecnoblog.net/noticias/partido-entra-no-stf-para-banir-ponto-eletronico-por-software-no-trabalho/
# Notícia encontrada: https://tecnoblog.net/noticias/brisanet-compra-licencas-de-5g-para-atuar-no-nordeste-e-centro-oeste/
# Notícia encontrada: https://tecnoblog.net/noticias/intel-core-12-geracao-bate-amd-desempenho-perde-eficiencia-energetica/
# Notícia encontrada: https://tecnoblog.net/noticias/ps5-sofre-aumento-de-preco-do-nada-e-fica-r-100-mais-caro-no-brasil/
# Notícia encontrada: https://tecnoblog.net/noticias/google-chrome-96-quebra-elementos-do-instagram-e-twitter-na-web/
# Notícia encontrada: https://tecnoblog.net/noticias/moto-g200-e-anunciado-com-camera-tripla-de-108-mp-e-tela-de-144-hz/
# Notícia encontrada: https://tecnoblog.net/noticias/miui-13-com-android-12-deve-ser-lancada-junto-ao-xiaomi-12/
# Notícia encontrada: https://tecnoblog.net/noticias/windows-11-expande-multitarefa-para-voce-alternar-entre-grupos-de-apps-abertos/
# Notícia encontrada: https://tecnoblog.net/noticias/com-escassez-de-chips-camara-quer-beneficio-a-industria-nacional-ate-2029/
# Notícia encontrada: https://tecnoblog.net/noticias/equipe-brasileira-vence-hackaton-internacional-de-open-finance-do-itau/
# Notícia encontrada: https://tecnoblog.net/noticias/paper-mario-sera-lancado-no-nintendo-switch-online/
# Notícia encontrada: https://tecnoblog.net/noticias/tamagotchi-ganha-edicoes-com-personagens-do-anime-demon-slayer/
# Notícia encontrada: https://tecnoblog.net/noticias/comedouro-inteligente-que-guarda-perfil-dos-gatos-chega-ao-brasil/
# Notícia encontrada: https://tecnoblog.net/noticias/fintench-n26-operacoes-brasil-2022-rival-nubank/
# Notícia encontrada: https://tecnoblog.net/noticias/flixbus-onibus-aplicativo-inicia-operacoes-brasil/
# Notícia encontrada: https://tecnoblog.net/noticias/mercado-livre-abre-armazem-para-agilizar-entregas-de-tvs-geladeiras-e-mais/
# Notícia encontrada: https://tecnoblog.net/noticias/motorola-inaugura-primeira-loja-conceito-no-nordeste-e-terceira-no-brasil/
# Notícia encontrada: https://tecnoblog.net/noticias/app-de-rotas-de-onibus-lanca-clube-quicko-e-da-ate-r-50-em-passagens/
# Notícia encontrada: https://tecnoblog.net/noticias/fortnite-vai-receber-jinx-de-lol-para-celebrar-estreia-de-arcane-na-netflix/
# Notícia encontrada: https://tecnoblog.net/noticias/ps5-se-aproxima-do-switch-em-vendas-mas-isso-nao-deve-durar-muito-tempo/
# Notícia encontrada: https://tecnoblog.net/noticias/projeto-de-lei-dificulta-cobranca-de-servicos-inuteis-na-conta-de-celular/
# Notícia encontrada: https://tecnoblog.net/noticias/google-docs-ganha-recurso-de-citacao-automatica-mas-nao-se-empolgue/
# Notícia encontrada: https://tecnoblog.net/noticias/chefe-da-produtora-de-apex-legends-assume-estudio-de-battlefield-2042/
# Notícia encontrada: https://tecnoblog.net/noticias/boeing-satelites-internet-reclamacao-spacex/
# Notícia encontrada: https://tecnoblog.net/noticias/na-briga-pelo-5g-claro-tim-e-vivo-garantem-espaco-na-faixa-mais-importante/
# Notícia encontrada: https://tecnoblog.net/noticias/nubank-libera-reserva-de-bdrs-para-estreia-na-bolsa-em-dezembro/
# Notícia encontrada: https://tecnoblog.net/noticias/microsoft-edge-tenta-convencer-voce-a-nao-baixar-google-chrome-no-windows/
# Notícia encontrada: https://tecnoblog.net/noticias/golpe-dos-nudes-policia-prende-quadrilha-que-deu-prejuizo-de-r-2-milhoes/
# Notícia encontrada: https://tecnoblog.net/noticias/wiz-lanca-fita-de-led-smart-e-controle-remoto-wizmote-no-brasil/
# Notícia encontrada: https://tecnoblog.net/noticias/nubank-como-operadora-de-celular-fintech-diz-ver-oportunidades-em-telecom/
# Notícia encontrada: https://tecnoblog.net/noticias/celular-android-menor-que-iphone-13-mini-e-lancado-por-marca-de-torradeiras/
# Notícia encontrada: https://tecnoblog.net/noticias/moto-g-power-2022-e-oficial-com-bateria-que-promete-durar-tres-dias/
# Notícia encontrada: https://tecnoblog.net/noticias/galaxy-a13-5g-celular-basico-da-samsung-vira-sem-carregador-e-fone/
# Notícia encontrada: https://tecnoblog.net/noticias/asus-zenfone-8-chega-ao-brasil-com-edicao-compacta-e-camera-de-64-mp/
# Notícia encontrada: https://tecnoblog.net/noticias/material-you-do-android-12-faz-jogos-travarem-por-causa-do-papel-de-parede/
# Notícia encontrada: https://tecnoblog.net/noticias/moto-g200-com-camera-de-108-mp-vaza-em-imagens-e-pode-ter-tela-de-144-hz/
# Notícia encontrada: https://tecnoblog.net/noticias/outback-inaugura-loja-no-cidade-alta-do-gta-com-missao-especial/
# Notícia encontrada: https://tecnoblog.net/noticias/xbox-series-xs-ganham-monitores-e-viram-videogames-portateis/
# Notícia encontrada: https://tecnoblog.net/noticias/discovery-streaming-com-irmaos-a-obra-revela-preco-de-lancamento-no-brasil/
# Notícia encontrada: https://tecnoblog.net/noticias/funcionarios-da-activision-blizzard-exigem-renuncia-do-ceo-apos-investigacao/
# Notícia encontrada: https://tecnoblog.net/noticias/asus-vivobook-13-slate-e-um-notebook-que-vira-tablet-com-tela-oled/
# Notícia encontrada: https://tecnoblog.net/noticias/galaxy-s21-e-google-pixel-6-ja-podem-ser-usados-para-abrir-portas-de-carros/
# Notícia encontrada: https://tecnoblog.net/noticias/whatsapp-trabalha-em-novos-apps-para-windows-e-mac-com-recursos-exclusivos/
# Notícia encontrada: https://tecnoblog.net/noticias/the-game-awards-2021-revela-indicados-do-premio-de-melhores-jogos-do-ano/
# Notícia encontrada: https://tecnoblog.net/noticias/snapdragon-g3x-gen-1-para-consoles-portateis-roda-jogos-a-ate-144-fps/
# Notícia encontrada: https://tecnoblog.net/noticias/instagram-volta-a-exibir-previa-com-foto-no-twitter-mas-e-mixuruca-%f0%9f%a4%8f/
# Notícia encontrada: https://tecnoblog.net/noticias/pac-man-estrela-edicao-especial-do-oneplus-nord-2-que-brilha-no-escuro/
# Notícia encontrada: https://tecnoblog.net/noticias/pix-mecanismo-de-devolucao-passa-a-valer-a-partir-desta-terca-feira-16/
# Notícia encontrada: https://tecnoblog.net/noticias/apos-caca-as-criptomoedas-china-coloca-pressao-em-metaverso-e-nfts/
# Notícia encontrada: https://tecnoblog.net/noticias/xbox-ganha-controle-especial-de-20-anos-com-carcaca-transparente/
# Notícia encontrada: https://tecnoblog.net/noticias/telegram-ganha-calendario-para-facilitar-busca-por-midias-em-conversas/
# Notícia encontrada: https://tecnoblog.net/noticias/veek-operadora-de-celular-com-internet-gratis-atinge-mais-de-4-mil-cidades/
# Notícia encontrada: https://tecnoblog.net/noticias/whatsapp-pay-rende-ate-r-25-em-cashback-para-clientes-do-banco-do-brasil/
# Notícia encontrada: https://tecnoblog.net/noticias/venda-da-oi-movel-e-aprovada-por-tecnicos-do-cade-mas-com-estas-condicoes/
# Notícia encontrada: https://tecnoblog.net/noticias/google-maps-vai-ajudar-a-evitar-multidoes-nas-compras-de-natal/
# Notícia encontrada: https://tecnoblog.net/noticias/tablet-android-lenovo-tab-p11-plus-lancamento-brasil/
# Notícia encontrada: https://tecnoblog.net/noticias/empresa-e-condenada-em-r-5-mil-por-violar-lgpd-com-celular-de-funcionaria/
# Notícia encontrada: https://tecnoblog.net/noticias/viajar-a-ate-800-km-h-hyperlooptt-mostra-design-de-capsula-para-passageiros/
# Notícia encontrada: https://tecnoblog.net/noticias/hacker-deve-pagar-multa-a-nintendo-e-ficar-10-anos-preso-por-pirataria/
# Notícia encontrada: https://tecnoblog.net/noticias/primeiro-video-do-youtube-critica-retirada-de-dislikes-ideia-estupida/
# Notícia encontrada: https://tecnoblog.net/noticias/instagram-mantem-perfil-hackeado-e-justica-condena-empresa-a-pagar-r-3-mil/
# Notícia encontrada: https://tecnoblog.net/noticias/telegram-de-sergio-moro-e-invadido-novamente-e-compartilha-pornografia/
# Notícia encontrada: https://tecnoblog.net/noticias/microsoft-linguagem-low-code-power-fx-codigo-aberto/
# Notícia encontrada: https://tecnoblog.net/noticias/spotify-wrapped-e-liberado-com-tudo-o-que-voce-mais-ouviu-em-2021/
# Notícia encontrada: https://tecnoblog.net/noticias/apple-fitness-e-lancado-no-brasil-com-treinos-e-meditacao-veja-preco/
# Notícia encontrada: https://tecnoblog.net/noticias/moto-g51-5g-e-oficial-com-novo-processador-snapdragon-480-plus/
# Notícia encontrada: https://tecnoblog.net/noticias/trilogia-max-payne-e-mais-de-70-jogos-agora-sao-retrocompativeis-no-xbox/
# Notícia encontrada: https://tecnoblog.net/noticias/projeto-de-lei-para-banir-pix-em-sao-paulo-tem-tramitacao-urgente-aprovada/
# Notícia encontrada: https://tecnoblog.net/noticias/galaxy-s22-entra-em-producao-em-massa-para-lancamento-no-inicio-de-2022/
# Notícia encontrada: https://tecnoblog.net/noticias/xiaomi-vai-abrir-sua-primeira-loja-oficial-no-nordeste-em-dezembro/
# Notícia encontrada: https://tecnoblog.net/noticias/ifood-nomes-de-restaurantes-sao-alterados-com-ataques-a-politicos-e-vacina/
# Notícia encontrada: https://tecnoblog.net/noticias/google-analisa-retorno-de-noticias-a-espanha-mediante-negociacao-com-jornais/
# Notícia encontrada: https://tecnoblog.net/noticias/bethesda-reforca-elder-scrolls-6-nao-vai-mesmo-sair-no-ps5/
# Notícia encontrada: https://tecnoblog.net/noticias/xiaomi-12-sera-um-dos-primeiros-celulares-com-snapdragon-8-gen-1/
# Notícia encontrada: https://tecnoblog.net/noticias/android-tv-12-com-melhorias-na-interface-e-em-privacidade-ganha-versao-final/
# Notícia encontrada: https://tecnoblog.net/noticias/new-world-perde-mais-de-70-dos-jogadores-desde-o-lancamento-no-steam/
# Notícia encontrada: https://tecnoblog.net/noticias/redmi-note-11t-5g-deve-chegar-ainda-em-novembro-com-camera-de-50-mp/
# Notícia encontrada: https://tecnoblog.net/noticias/facebook-vai-encerrar-reconhecimento-facial-por-preocupacao-com-a-tecnologia/
# Notícia encontrada: https://tecnoblog.net/noticias/e-mail-do-fbi-e-hackeado-e-usado-para-mandar-spam-difamando-pesquisador/
# Notícia encontrada: https://tecnoblog.net/noticias/dona-da-americanas-e-submarino-lidera-queixas-da-black-friday-no-procon-sp/
# Notícia encontrada: https://tecnoblog.net/noticias/ibm-anuncia-processador-quantico-eagle-127-qubits/
# Notícia encontrada: https://tecnoblog.net/noticias/snapdragon-8-gen-1-para-celulares-filma-em-8k-hdr-e-tem-5g-ultrarrapido/
# Notícia encontrada: https://tecnoblog.net/noticias/casas-bahia-pede-de-volta-galaxy-note-20-de-r-679-que-ainda-nem-foi-entregue/
# Notícia encontrada: https://tecnoblog.net/noticias/instagram-libera-sticker-use-a-sua-que-permite-criar-correntes-em-stories/
# Notícia encontrada: https://tecnoblog.net/noticias/receita-faz-leilao-de-iphone-11-xbox-series-s-e-mais-itens-apreendidos/
# Notícia encontrada: https://tecnoblog.net/noticias/roblox-e-mais-jogos-ajudam-psicologos-a-tratar-ansiedade-em-criancas/
# Notícia encontrada: https://tecnoblog.net/noticias/android-12-no-brasil-confira-lista-oficial-da-samsung-para-celulares-galaxy/
# Notícia encontrada: https://tecnoblog.net/noticias/nubank-reduz-faixa-de-preco-de-acoes-para-estreia-na-bolsa-de-valores/
# Notícia encontrada: https://tecnoblog.net/noticias/streamer-que-bateu-recorde-na-twitch-migra-para-youtube-gaming/
# Notícia encontrada: https://tecnoblog.net/noticias/procon-sp-firma-termo-com-facily-que-tera-que-reduzir-reclamacoes-em-80/
# Notícia encontrada: https://tecnoblog.net/noticias/positivo-lanca-2a-geracao-de-smart-camera-wi-fi-que-e-mais-facil-de-instalar/
# Notícia encontrada: https://tecnoblog.net/noticias/as-novidades-do-amazon-prime-video-no-brasil-em-dezembro/
# Notícia encontrada: https://tecnoblog.net/noticias/whatsapp-pode-permitir-apagar-mensagens-para-todos-apos-meses-de-envio/
# Notícia encontrada: https://tecnoblog.net/noticias/instagram-ja-pagou-ate-r-200-mil-por-videos-no-reels-rival-do-tiktok/
# Notícia encontrada: https://tecnoblog.net/noticias/android-auto-deixara-voce-escolher-qual-operadora-4g-usar-no-carro/
# Notícia encontrada: https://tecnoblog.net/noticias/tse-acha-5-falhas-na-urna-eletronica-mas-diz-que-nenhuma-altera-eleicoes/
# Notícia encontrada: https://tecnoblog.net/noticias/nubank-vai-oferecer-acoes-de-graca-a-milhoes-de-clientes-em-ipo/
# Notícia encontrada: https://tecnoblog.net/noticias/free-fire-e-la-casa-de-papel-vao-colaborar-em-mais-um-evento-tematico/
# Notícia encontrada: https://tecnoblog.net/noticias/among-us-anuncia-crossover-com-arcane-de-league-of-legends/
# Notícia encontrada: https://tecnoblog.net/noticias/casas-bahia-vai-honrar-compras-do-s20-fe-a-r-1-mil-mas-nao-do-note-20/
# Notícia encontrada: https://tecnoblog.net/noticias/apple-lanca-beats-fit-pro-fones-cancelamento-ruido-recursos-airpods/
# Notícia encontrada: https://tecnoblog.net/noticias/raspberry-pi-4-e-pi-400-agora-rodam-android-12-gracas-a-desenvolvedor/
# Notícia encontrada: https://tecnoblog.net/noticias/rival-da-loggi-e-rappi-lalamove-chega-a-16-cidades-do-brasil/
# Notícia encontrada: https://tecnoblog.net/noticias/xbox-cloud-recebe-mais-definicao-para-quem-joga-no-microsoft-edge/
# Notícia encontrada: https://tecnoblog.net/noticias/windows-10-recebe-loja-de-apps-do-windows-11-com-estas-novidades/
# Notícia encontrada: https://tecnoblog.net/noticias/windows-11-impede-truque-que-permitia-abrir-links-fora-do-microsoft-edge/
# Notícia encontrada: https://tecnoblog.net/noticias/rocket-league-sideswipe-e-liberado-no-mundo-todo-para-android-e-ios/
# Notícia encontrada: https://tecnoblog.net/noticias/whatsapp-vai-expandir-guia-de-negocios-para-mais-empresas-e-locais/
# Notícia encontrada: https://tecnoblog.net/noticias/spotify-compra-plataforma-de-audiobooks-rival-da-amazon/
# Notícia encontrada: https://tecnoblog.net/noticias/agora-vai-samsung-galaxy-s21-fe-aparece-em-imagens-de-divulgacao-vazadas/
# Notícia encontrada: https://tecnoblog.net/noticias/mercado-livre-forma-alianca-contra-produtos-falsos-da-levis-e-outras-marcas/
# Notícia encontrada: https://tecnoblog.net/noticias/samsung-sofre-com-falta-de-chips-para-celulares-no-brasil-e-motorola-cresce/
# Notícia encontrada: https://tecnoblog.net/noticias/spotify-oferece-premium-gratis-por-3-meses-e-oferta-a-quem-cancelou-o-plano/
# Notícia encontrada: https://tecnoblog.net/noticias/ifood-passa-a-cobrar-taxa-de-servico-em-pedidos-com-valor-de-ate-r-20/
# Notícia encontrada: https://tecnoblog.net/noticias/versao-2-3-de-genshin-impact-traz-dois-novos-personagens-e-tema-de-animais/
# Notícia encontrada: https://tecnoblog.net/noticias/xiaomi-explica-por-que-celulares-com-mediatek-demoram-mais-para-receber-updates/
# Notícia encontrada: https://tecnoblog.net/noticias/mais-um-xiaomi-redmi-note-11t-5g-e-oficial-com-camera-dupla-de-50-mp/
# Notícia encontrada: https://tecnoblog.net/noticias/banco-inter-cria-inter-pass-assinatura-com-cashback-extra-e-beneficios/
# Notícia encontrada: https://tecnoblog.net/noticias/tesla-troca-chip-intel-por-amd-ryzen-em-carros-eletricos-model-y/
# Notícia encontrada: https://tecnoblog.net/noticias/novo-seguro-cobre-perdas-financeiras-causadas-por-vazamento-de-dados/
# Notícia encontrada: https://tecnoblog.net/noticias/kernel-linux-5-15-suporte-melhorado-ntfs-intel-arc-apple-m1/
# Notícia encontrada: https://tecnoblog.net/noticias/projeto-quer-alimentacao-e-seguro-a-entregadores-do-ifood-uber-eats-e-rappi/
# Notícia encontrada: https://tecnoblog.net/noticias/procon-sp-notifica-casas-bahia-por-cancelar-pedidos-de-note-20-por-r-679/
# Notícia encontrada: https://tecnoblog.net/noticias/decisao-do-stj-envolvendo-airbnb-nao-deve-afetar-alugueis-de-fim-de-ano/
# Notícia encontrada: https://tecnoblog.net/noticias/microsoft-edge-chega-versao-estavel-linux/
# Notícia encontrada: https://tecnoblog.net/noticias/primeiro-iphone-do-mundo-com-porta-usb-c-e-vendido-por-mais-de-r-450-mil/
# Notícia encontrada: https://tecnoblog.net/noticias/cyberpunk-2077-chega-para-ps5-e-xbox-series-com-dlc-no-inicio-de-2022/
# Notícia encontrada: https://tecnoblog.net/noticias/whatsapp-comeca-a-liberar-cashback-em-pagamentos-pelo-app/
# Notícia encontrada: https://tecnoblog.net/noticias/apple-encerra-vendas-de-mais-um-mac-com-intel-em-transicao-para-m1/
# Notícia encontrada: https://tecnoblog.net/noticias/ps5-completa-um-ano-e-sony-revela-os-games-mais-jogados/
# Notícia encontrada: https://tecnoblog.net/noticias/casas-bahia-vende-galaxy-note-20-a-r-679-cancela-pedidos-e-irrita-clientes/
# Notícia encontrada: https://tecnoblog.net/noticias/vendas-de-gta-remastered-para-pc-sao-suspensas-pela-rockstar-apos-queixas/
# Notícia encontrada: https://tecnoblog.net/noticias/as-novidades-no-catalogo-do-star-para-dezembro/
# Notícia encontrada: https://tecnoblog.net/noticias/whatsapp-para-de-funcionar-em-celulares-com-versao-muito-antiga-do-android/
# Notícia encontrada: https://tecnoblog.net/noticias/windows-11-vai-facilitar-compartilhar-a-tela-no-microsoft-teams-e-mais-apps/
# Notícia encontrada: https://tecnoblog.net/noticias/moto-g71-da-motorola-e-homologado-pela-anatel-para-venda-no-brasil/
# Notícia encontrada: https://tecnoblog.net/noticias/magazine-luiza-segue-bb-e-cria-consorcio-gamer-de-ate-r-14-mil/
# Notícia encontrada: https://tecnoblog.net/noticias/zelda-ocarina-of-time-do-n64-passa-por-engenharia-reversa-para-receber-mods/
# Notícia encontrada: https://tecnoblog.net/noticias/redmi-smart-band-pro-e-uma-pulseira-da-xiaomi-com-bateria-de-ate-20-dias/
# Notícia encontrada: https://tecnoblog.net/noticias/discord-interrompe-planos-de-integrar-nfts-apos-furia-e-boicote-de-usuarios/
# Notícia encontrada: https://tecnoblog.net/noticias/tim-sync-leva-4g-ao-apple-watch-para-clientes-do-pos-pago-e-controle/
# Notícia encontrada: https://tecnoblog.net/noticias/pl-das-fake-news-frente-digital-da-camara-tenta-frear-tramitacao-relampago/
# Notícia encontrada: https://tecnoblog.net/noticias/as-novidades-do-catalogo-do-disney-em-dezembro/
# Notícia encontrada: https://tecnoblog.net/noticias/jogador-bate-recorde-e-termina-super-mario-odyssey-em-menos-de-uma-hora/
# Notícia encontrada: https://tecnoblog.net/noticias/apple-e-condenada-a-indenizar-consumidora-por-iphone-11-sem-carregador/
# Notícia encontrada: https://tecnoblog.net/noticias/youtube-remove-nova-live-de-bolsonaro-publicada-em-canal-de-seu-filho-carlos/
# Notícia encontrada: https://tecnoblog.net/noticias/xbox-para-pc-segue-steam-e-deixa-voce-instalar-jogos-na-pasta-que-quiser/
# Notícia encontrada: https://tecnoblog.net/noticias/ceo-do-twitter-jack-dorsey-deixa-cargo-e-explica-motivos-para-saida/
# Notícia encontrada: https://tecnoblog.net/noticias/oi-ve-prejuizo-crescer-em-865-apesar-de-bom-desempenho-na-fibra/
# Notícia encontrada: https://tecnoblog.net/noticias/pre-venda-de-homem-aranha-sem-volta-para-casa-dara-nfts-a-alguns-sortudos/
# Notícia encontrada: https://tecnoblog.net/noticias/novo-golpe-do-pix-mira-micro-e-pequenos-empreendedores/
# Notícia encontrada: https://tecnoblog.net/noticias/cyberpunk-2077-adia-dlc-gratuito-e-demais-atualizacoes-para-2022/
# Notícia encontrada: https://tecnoblog.net/noticias/metade-das-criancas-de-ate-12-anos-no-brasil-ja-tem-celular-proprio/
# Notícia encontrada: https://tecnoblog.net/noticias/wow-shadowlands-promete-final-epico-no-patch-9-2-ultimo-update-da-expansao/
# Notícia encontrada: https://tecnoblog.net/noticias/nintendo-switch-libera-aplicativo-da-twitch-para-download-na-eshop/
# Notícia encontrada: https://tecnoblog.net/noticias/apple-vai-ter-que-indenizar-advogado-por-iphone-12-roubado-e-invadido/
# Notícia encontrada: https://tecnoblog.net/noticias/xiaomi-vai-usar-mi-stores-para-vender-seu-proprio-carro-eletrico/
# Notícia encontrada: https://tecnoblog.net/noticias/facebook-derruba-1-milhao-de-fake-news-no-brasil-mas-esconde-o-essencial/
# Notícia encontrada: https://tecnoblog.net/noticias/xiaomi-prepara-miui-13-baseada-no-android-11-e-12-para-estes-celulares/
# Notícia encontrada: https://tecnoblog.net/noticias/google-fotos-tera-pasta-segura-no-iphone-para-guardar-nudes-e-outras-imagens/
# Notícia encontrada: https://tecnoblog.net/noticias/disney-desacelera-e-cresce-menos-que-netflix-em-numero-de-assinantes/
# Notícia encontrada: https://tecnoblog.net/noticias/neymar-e-banido-no-steam-sem-mais-nem-menos/
# Notícia encontrada: https://tecnoblog.net/noticias/assassins-creed-infinity-sera-pago-e-online-com-varias-campanhas-unicas/
# Notícia encontrada: https://tecnoblog.net/noticias/twitter-cria-divisao-cripto-para-tirar-planos-de-descentralizacao-do-papel/
# Notícia encontrada: https://tecnoblog.net/noticias/youtubers-fazem-criancas-de-portugal-falarem-brasileiro-e-irritam-adultos/
# Notícia encontrada: https://tecnoblog.net/noticias/google-meet-avisa-que-vai-remover-gravacao-de-video-em-planos-mais-baratos/
# Notícia encontrada: https://tecnoblog.net/noticias/amazon-inaugura-centro-de-distribuicao-no-ceara-para-entregas-no-nordeste/
# Notícia encontrada: https://tecnoblog.net/noticias/leilao-da-receita-federal-em-curitiba-tem-xiaomi-iphone-switch-e-mais/
# Notícia encontrada: https://tecnoblog.net/noticias/canonical-multipass-virtualizacao-ubuntu-linux-mac-m1/
# Notícia encontrada: https://tecnoblog.net/noticias/genshin-impact-pode-ter-nova-regiao-de-enkanomiya-no-proximo-patch/
# Notícia encontrada: https://tecnoblog.net/noticias/whatsapp-comeca-a-integrar-carteira-digital-da-meta-dona-do-facebook/
# Notícia encontrada: https://tecnoblog.net/noticias/motorola-edge-30-ultra-e-moto-g31-vazam-com-modulo-oval-de-camera-tripla/
# Notícia encontrada: https://tecnoblog.net/noticias/pix-3a-fase-do-open-banking-facilita-pagamento-em-sites-sem-app-do-banco/
# Notícia encontrada: https://tecnoblog.net/noticias/apple-facilita-troca-de-bateria-do-novo-macbook-pro-mostra-ifixit/
# Notícia encontrada: https://tecnoblog.net/noticias/facebook-epic-games-roblox-e-microsoft-querem-um-pedaco-do-metaverso/
# Notícia encontrada: https://tecnoblog.net/noticias/ifixit-desmonta-pano-da-apple-que-custa-r-219-com-direito-a-microscopio/
# Notícia encontrada: https://tecnoblog.net/noticias/disparos-em-massa-via-whatsapp-vao-dar-cadeia-avisa-alexandre-de-moraes/
# Notícia encontrada: https://tecnoblog.net/noticias/raspberry-ppi-zero-2-w-placa-cinco-vezes-mais-processamento/
# Notícia encontrada: https://tecnoblog.net/noticias/vivo-tem-lucro-de-r-131-bi-e-aumenta-meta-para-expansao-de-fibra-optica/
# Notícia encontrada: https://tecnoblog.net/noticias/galaxy-m52-5g-chega-ao-brasil-com-snapdragon-778g-e-suporte-para-ram-plus/
# Notícia encontrada: https://tecnoblog.net/noticias/android-12-ganha-ferramenta-para-criacao-de-apps-com-material-you/
# Notícia encontrada: https://tecnoblog.net/noticias/fones-redmi-buds-3-pro-com-anc-e-xiaomi-pad-5-chegam-ao-brasil/
# Notícia encontrada: https://tecnoblog.net/noticias/xiaomi-11-lite-5g-ne-chega-ao-brasil-com-tela-de-90-hz-e-snapdragon-778g/
# Notícia encontrada: https://tecnoblog.net/noticias/microsoft-reducao-consumo-agua-resfriamento-datacenters/
# Notícia encontrada: https://tecnoblog.net/noticias/redmi-watch-2-e-o-novo-relogio-barato-da-xiaomi-com-oximetro-de-pulso/
# Notícia encontrada: https://tecnoblog.net/noticias/samsung-tem-receita-recorde-gracas-a-chips-e-celulares-galaxy-dobraveis/
# Notícia encontrada: https://tecnoblog.net/noticias/ps5-chega-a-134-milhoes-de-vendas-mas-sony-deixa-de-lucrar-com-games/
# Notícia encontrada: https://tecnoblog.net/noticias/xiaomi-redmi-note-11-pro-e-oficial-com-camera-tripla-e-recarga-de-ate-120-w/
# Notícia encontrada: https://tecnoblog.net/noticias/ios-15-2-beta-mostra-quais-apps-estao-acessando-seus-dados-no-iphone/
# Notícia encontrada: https://tecnoblog.net/noticias/bolsonaro-recorre-ao-stf-para-barrar-suspensao-em-redes-sociais/
# Notícia encontrada: https://tecnoblog.net/noticias/adobe-photoshop-vai-ajudar-a-combater-falsificacao-de-nft/
# Notícia encontrada: https://tecnoblog.net/noticias/amazon-astro-robo-domestico-interage-vigia-casa/
# Notícia encontrada: https://tecnoblog.net/noticias/king-of-fighters-15-tera-beta-aberto-em-novembro-e-dolores-como-lutadora/
# Notícia encontrada: https://tecnoblog.net/noticias/parque-de-super-mario-no-japao-recebera-area-de-donkey-kong/
# Notícia encontrada: https://tecnoblog.net/noticias/governo-notifica-apple-e-samsung-e-da-15-dias-para-acordo-sobre-carregadores/
# Notícia encontrada: https://tecnoblog.net/noticias/campainha-pense-bem-e-um-videoporteiro-da-tectoy-que-passou-na-anatel/
# Notícia encontrada: https://tecnoblog.net/noticias/amazon-glow-une-camera-e-projetor-para-divertir-criancas-e-adultos/
# Notícia encontrada: https://tecnoblog.net/noticias/google-anuncia-android-12l-otimizado-para-tablets-e-celulares-dobraveis/
# Notícia encontrada: https://tecnoblog.net/noticias/fortnite-tera-show-musical-do-rapper-brasileiro-emicida/
# Notícia encontrada: https://tecnoblog.net/noticias/xbox-series-x-e-s-recebem-dolby-vision-que-melhora-o-visual-dos-jogos/
# Notícia encontrada: https://tecnoblog.net/noticias/halo-view-e-uma-pulseira-fitness-da-amazon-com-oximetro-de-pulso/
# Notícia encontrada: https://tecnoblog.net/noticias/testes-independentes-apple-m1-pro-max-comprovam-alto-desempenho/
# Notícia encontrada: https://tecnoblog.net/noticias/amazon-echo-show-15-tela-inteligente/
# Notícia encontrada: https://tecnoblog.net/noticias/amazon-echo-frames-oculos-com-alexa-ganham-novas-cores-e-modo-sono/
# Notícia encontrada: https://tecnoblog.net/noticias/google-meet-comeca-a-liberar-legendas-com-traducao-ao-vivo-em-portugues/
# Notícia encontrada: https://tecnoblog.net/noticias/new-world-e-lancado-pela-amazon-com-missao-de-superar-wow-e-final-fantasy-14/
# Notícia encontrada: https://tecnoblog.net/noticias/marvels-avengers-chega-esta-semana-ao-xbox-game-pass-mas-sem-homem-aranha/
# Notícia encontrada: https://tecnoblog.net/noticias/samsung-vai-levar-one-ui-do-android-para-pcs-com-windows-11/
# Notícia encontrada: https://tecnoblog.net/noticias/instagram-libera-figurinha-de-link-para-todos-veja-como-voce-pode-usar/
# Notícia encontrada: https://tecnoblog.net/noticias/jogador-e-removido-de-fifa-22-apos-acusacoes-de-abuso-sexual/
# Notícia encontrada: https://tecnoblog.net/noticias/nubank-entra-com-pedido-para-estrear-em-bolsa-de-valores-no-brasil-e-eua/
# Notícia encontrada: https://tecnoblog.net/noticias/apple-music-chega-ao-ps5-com-opcao-de-escutar-musicas-enquanto-joga/
# Notícia encontrada: https://tecnoblog.net/noticias/ceo-da-microsoft-tentativa-de-compra-do-tiktok-foi-a-coisa-mais-estranha/
# Notícia encontrada: https://tecnoblog.net/noticias/spotify-retorna-ao-lucro-e-chega-a-172-milhoes-de-assinantes-no-premium/
# Notícia encontrada: https://tecnoblog.net/noticias/allugator-oferece-investimento-em-iphone-13-que-rende-17-ao-ano/
# Notícia encontrada: https://tecnoblog.net/noticias/iphone-13-perde-face-id-em-caso-de-troca-de-tela-em-assistencia-terceirizada/
# Notícia encontrada: https://tecnoblog.net/noticias/notch-do-macbook-pro-cria-problemas-para-programas-do-macos/
# Notícia encontrada: https://tecnoblog.net/noticias/iphone-13-mini-supera-iphone-12-pro-em-teste-de-camera-do-dxomark/
# ...
# Notícia encontrada: https://tecnoblog.net/noticias/claro-tv-libera-acesso-ao-apple-tv-sem-mexer-no-preco-de-super-bundle/
# Notícia encontrada: https://tecnoblog.net/noticias/cresce-o-interesse-por-tvs-gigantes-no-brasil/
# Notícia encontrada: https://tecnoblog.net/noticias/whatsapp-vai-facilitar-acesso-a-configuracoes-de-privacidade-e-seguranca/
# Notícia encontrada: https://tecnoblog.net/noticias/apple-pode-acabar-com-opcao-de-8-gb-nos-macs-com-m4/
# Notícia encontrada: https://tecnoblog.net/noticias/google-testa-mudanca-para-deixar-android-mais-rapido/
# Notícia encontrada: https://tecnoblog.net/noticias/samsung-libera-funcao-circule-para-pesquisar-em-celulares-galaxy-a/
# Notícia encontrada: https://tecnoblog.net/noticias/apple-marca-lancamento-do-iphone-16-para-9-de-setembro/
# Notícia encontrada: https://tecnoblog.net/noticias/threads-testa-publicacoes-que-somem-apos-24-horas/
# Notícia encontrada: https://tecnoblog.net/noticias/xiaomi-tem-novo-fone-aprovado-na-anatel-dias-apos-lancamento-global/
# Notícia encontrada: https://tecnoblog.net/noticias/windows-11-podera-ter-atualizacoes-que-nao-reiniciam-o-pc/
# Notícia encontrada: https://tecnoblog.net/noticias/microsoft-recua-da-decisao-de-remover-painel-de-controle-do-windows/
# Notícia encontrada: https://tecnoblog.net/noticias/google-deixa-escapar-que-android-15-sera-lancado-em-outubro/
# Notícia encontrada: https://tecnoblog.net/noticias/pc-portatil-asus-rog-ally-x-e-homologado-na-anatel-e-pode-ser-lancado-em-breve/
# Notícia encontrada: https://tecnoblog.net/noticias/dc-roma-pad-ii-e-um-tablet-com-chip-risc-v-e-ubuntu-linux/
# Notícia encontrada: https://tecnoblog.net/noticias/x-twitter-testa-ferramenta-de-reunioes-por-videoconferencia/
# Notícia encontrada: https://tecnoblog.net/noticias/presenca-do-linux-em-pcs-cresceu-expressivamente-em-2024/
# Notícia encontrada: https://tecnoblog.net/noticias/tvs-da-samsung-terao-7-anos-de-atualizacoes-do-tizen-diz-executivo/
# Notícia encontrada: https://tecnoblog.net/noticias/instagram-abandona-os-populares-filtros-ar-feitos-por-creators/
# Notícia encontrada: https://tecnoblog.net/noticias/motorola-edge-50-neo-e-razr-50-passam-na-anatel-e-podem-ser-lancados-no-brasil/
# Notícia encontrada: https://tecnoblog.net/noticias/instagram-libera-novas-fontes-e-funcao-que-adiciona-texto-em-fotos/
# Notícia encontrada: https://tecnoblog.net/noticias/instagram-quer-mostrar-o-que-voce-esta-ouvindo-como-nos-tempos-do-msn/
# Notícia encontrada: https://tecnoblog.net/noticias/xiaomi-anuncia-fim-das-atualizacoes-para-o-poco-f3-e-outros-celulares/
# Notícia encontrada: https://tecnoblog.net/noticias/atualizacao-do-windows-11-aumenta-desempenho-de-chips-ryzen-em-jogos/
# Notícia encontrada: https://tecnoblog.net/noticias/notepin-resume-reunioes-usando-ia-e-pode-ser-usado-como-pulseira-ou-colar/
# Notícia encontrada: https://tecnoblog.net/noticias/operacao-da-pf-investiga-grupo-que-movimentou-r-80-mi-com-venda-de-eletronicos/
# Notícia encontrada: https://tecnoblog.net/noticias/versao-paga-e-mais-esperta-da-alexa-deve-chegar-em-outubro/
# Notícia encontrada: https://tecnoblog.net/noticias/claro-faz-misterio-mas-libera-esim-aos-poucos-em-app-de-android/
# Notícia encontrada: https://tecnoblog.net/noticias/cartoes-da-flash-ganham-compatibilidade-com-apple-pay-veja-como-adicionar/
# Notícia encontrada: https://tecnoblog.net/noticias/apos-polemica-gemini-voltara-a-gerar-imagens-de-pessoas/
# Notícia encontrada: https://tecnoblog.net/noticias/asus-lanca-notebook-zenbook-s-16-com-chip-amd-ryzen-ai-no-brasil/
# Notícia encontrada: https://tecnoblog.net/noticias/samsung-avisa-usar-carregadores-de-ma-qualidade-pode-fazer-seu-celular-descascar/
# Notícia encontrada: https://tecnoblog.net/noticias/iphone-17-pro-max-pode-ser-o-unico-com-12-gb-de-ram/
# Notícia encontrada: https://tecnoblog.net/noticias/stf-bloqueia-contas-bancarias-da-starlink-para-cobrar-multas-do-x/
# Notícia encontrada: https://tecnoblog.net/noticias/motorola-revela-edge-50-neo-antes-da-hora-no-reino-unido/
# Notícia encontrada: https://tecnoblog.net/noticias/stf-intima-elon-musk-e-ameaca-tirar-x-do-ar-em-24-horas/
# Notícia encontrada: https://tecnoblog.net/noticias/agora-voce-pode-divulgar-canais-do-youtube-usando-qr-code/
# Notícia encontrada: https://tecnoblog.net/noticias/spotify-reclama-de-mudanca-nos-botoes-de-volume-do-iphone/
# Notícia encontrada: https://tecnoblog.net/noticias/11-horas-depois-o-x-twitter-nao-caiu/
# Notícia encontrada: https://tecnoblog.net/noticias/variante-do-galaxy-z-fold-6-pode-chegar-ainda-em-2024/
# Notícia encontrada: https://tecnoblog.net/noticias/versao-especial-do-galaxy-z-fold-6-pode-ter-camera-de-200-mp/
# Notícia encontrada: https://tecnoblog.net/noticias/anpd-libera-meta-para-treinar-ia-com-dados-pessoais/
# Notícia encontrada: https://tecnoblog.net/noticias/whatsapp-testa-funcao-para-criar-listas-de-contatos-e-grupos/
# Notícia encontrada: https://tecnoblog.net/noticias/linux-podera-mostrar-qr-code-em-kernel-panic-para-ajudar-a-resolver-erro/
# Notícia encontrada: https://tecnoblog.net/noticias/exclusivo-galaxy-tab-s10-e-homologado-pela-anatel/
# Notícia encontrada: https://tecnoblog.net/noticias/google-play-store-podera-baixar-ate-tres-apps-ao-mesmo-tempo/
# Notícia encontrada: https://tecnoblog.net/noticias/android-vai-parar-de-chamar-carregadores-nao-tao-rapidos-assim-de-rapidos/
# Notícia encontrada: https://tecnoblog.net/noticias/twitter-fora-do-ar-justica-ordena-que-anatel-apple-e-google-impecam-acesso/
# Notícia encontrada: https://tecnoblog.net/noticias/alexandre-de-moraes-impoe-multa-a-quem-usar-vpn-para-acessar-x-twitter/
# Notícia encontrada: https://tecnoblog.net/noticias/a-ideia-de-criar-o-brazap-e-um-factoide-diz-presidente-da-abdi/
# Notícia encontrada: https://tecnoblog.net/noticias/xiaomi-prepara-lancamento-do-redmi-14c-e-xiaomi-band-9-no-brasil/
# Notícia encontrada: https://tecnoblog.net/noticias/proxima-geracao-da-alexa-deve-usar-tecnologia-do-claude-ai/
# Notícia encontrada: https://tecnoblog.net/noticias/samsung-lanca-galaxy-a06-no-brasil-veja-preco/
# Notícia encontrada: https://tecnoblog.net/noticias/intel-reforca-que-chips-core-para-notebooks-nao-sao-afetados-por-falha/
# Notícia encontrada: https://tecnoblog.net/noticias/ame-da-americanas-vai-encerrar-contas-saiba-ate-quando-usar-seu-saldo/
# Notícia encontrada: https://tecnoblog.net/noticias/samsung-deve-usar-snapdragon-em-todos-os-galaxy-s25/
# Notícia encontrada: https://tecnoblog.net/noticias/whatsapp-testa-senha-para-proteger-nomes-de-usuario-de-mensagens-indevidas/
# Notícia encontrada: https://tecnoblog.net/noticias/forte-crise-pode-fazer-intel-vender-divisoes-e-cortar-custos/
# Notícia encontrada: https://tecnoblog.net/noticias/claro-tim-e-vivo-iniciam-bloqueio-do-x-twitter-no-brasil/
# Notícia encontrada: https://tecnoblog.net/noticias/correios-rastreamento-internacional-prazo-entrega/
# Notícia encontrada: https://tecnoblog.net/noticias/mac-mini-com-m4-pode-vir-sem-portas-usb-a/
# Notícia encontrada: https://tecnoblog.net/noticias/samsung-confirma-lancamento-do-galaxy-ring-no-brasil-para-este-mes/
# Notícia encontrada: https://tecnoblog.net/noticias/exclusivo-galaxy-tab-s10-ultra-passa-na-anatel-com-s-pen-de-2023/
# Notícia encontrada: https://tecnoblog.net/noticias/agora-e-a-vez-da-orange-pi-lancar-uma-placa-com-chip-risc-v/
# Notícia encontrada: https://tecnoblog.net/noticias/iphone-se-de-4a-geracao-pode-usar-display-oled/
# Notícia encontrada: https://tecnoblog.net/noticias/intel-lanca-chips-xeon-com-ate-60-nucleos-para-workstations/
# Notícia encontrada: https://tecnoblog.net/noticias/intel-anuncia-chips-core-ultra-200v-para-brigar-com-amd-e-qualcomm-em-ia/
# Notícia encontrada: https://tecnoblog.net/noticias/anatel-adia-novas-regras-sobre-direitos-do-consumidor-para-setembro-de-2025/
# Notícia encontrada: https://tecnoblog.net/noticias/vivo-amazon-prime/
# Notícia encontrada: https://tecnoblog.net/noticias/estudo-da-oms-afirma-que-celulares-nao-causam-cancer/
# Notícia encontrada: https://tecnoblog.net/noticias/consultoria-avalia-rede-5g-das-operadoras-brasileiras-veja-os-resultados/
# Notícia encontrada: https://tecnoblog.net/noticias/starlink-acata-ordem-da-anatel-e-vai-bloquear-acesso-ao-x-twitter/
# Notícia encontrada: https://tecnoblog.net/noticias/mercado-livre-reformula-meli-com-dois-planos-veja-precos/
# Notícia encontrada: https://tecnoblog.net/noticias/android-15-e-anunciado-oficialmente-mas-ainda-nao-chegara-a-seu-celular/
# Notícia encontrada: https://tecnoblog.net/noticias/por-que-recebi-email-sobre-a-ia-da-meta-aviso-chega-a-milhoes-de-pessoas/
# Notícia encontrada: https://tecnoblog.net/noticias/spotify-daylist-playlist-que-muda-ao-longo-do-dia-chega-ao-brasil/
# Notícia encontrada: https://tecnoblog.net/noticias/galaxy-z-flip-tab-s7-e-s7-chegam-ao-fim-do-suporte-de-atualizacoes/
# Notícia encontrada: https://tecnoblog.net/noticias/motorola-prepara-lancamento-do-moto-g55-no-brasil/
# Notícia encontrada: https://tecnoblog.net/noticias/ceo-da-qualcomm-cogita-lancar-chips-snapdragon-para-desktops/
# Notícia encontrada: https://tecnoblog.net/noticias/meta-obtem-vitoria-no-brasil-para-compartilhar-dados/
# Notícia encontrada: https://tecnoblog.net/noticias/starlink-estacoes-terrestres-brasil/
# Notícia encontrada: https://tecnoblog.net/noticias/coleta-de-dados-biometricos-preocupa-60-dos-brasileiros-segundo-pesquisa/
# Notícia encontrada: https://tecnoblog.net/noticias/acer-dualplay-e-um-conceito-de-notebook-gamer-com-gamepad-acoplavel/
# Notícia encontrada: https://tecnoblog.net/noticias/57-do-conteudo-na-web-foi-criado-por-robos-mostra-estudo/
# Notícia encontrada: https://tecnoblog.net/noticias/funcoes-do-copilot-chegarao-a-notebooks-amd-e-intel-em-novembro/
# Notícia encontrada: https://tecnoblog.net/noticias/lenovo-lanca-novos-notebooks-com-chips-amd-intel-e-qualcomm-na-ifa-2024/
# Notícia encontrada: https://tecnoblog.net/noticias/bluetooth-6-0-e-oficial-e-promete-melhorar-rastreamento-de-dispositivos/
# Notícia encontrada: https://tecnoblog.net/noticias/navegador-propoe-solucao-para-interminaveis-janelas-de-cookies/
# Notícia encontrada: https://tecnoblog.net/noticias/intel-desiste-de-produzir-chips-com-processo-20a-para-reduzir-custos/
# Notícia encontrada: https://tecnoblog.net/noticias/versao-especial-do-galaxy-z-fold-6-pode-ter-esse-visual/
# Notícia encontrada: https://tecnoblog.net/noticias/asus-revela-minipc-que-traz-botao-copilot-no-proprio-gabinete/
# Notícia encontrada: https://tecnoblog.net/noticias/robo-controlado-por-cogumelo-e-novo-passo-na-criacao-de-bio-robos/
# Notícia encontrada: https://tecnoblog.net/noticias/qualcomm-teria-cogitado-comprar-divisao-da-intel-para-crescer-em-pcs/
# Notícia encontrada: https://tecnoblog.net/noticias/sites-da-globo-ficam-fora-do-ar-na-manha-desta-sexta-feira/
# Notícia encontrada: https://tecnoblog.net/noticias/musico-e-acusado-de-fraude-milionaria-em-streaming-usando-ia-e-robos/
# Notícia encontrada: https://tecnoblog.net/noticias/telegram-altera-regras-e-informa-sobre-denuncia-de-conteudo-ilegal/
# Notícia encontrada: https://tecnoblog.net/noticias/notebook-com-tela-giratoria-impressiona-visitantes-de-feira-na-alemanha/
# Notícia encontrada: https://tecnoblog.net/noticias/meta-revela-como-whatsapp-vai-conversar-com-outros-apps-na-europa/
# Notícia encontrada: https://tecnoblog.net/noticias/hmd-anuncia-smartphone-modular-que-tem-ate-ring-light/
# Notícia encontrada: https://tecnoblog.net/noticias/pix-esta-fora-do-ar-para-itau-caixa-e-mais-bancos-nesta-sexta-feira-6/
# Notícia encontrada: https://tecnoblog.net/noticias/amd-vai-focar-em-gpus-intermediarias-para-enfrentar-nvidia/
# Notícia encontrada: https://tecnoblog.net/noticias/o-ios-18-e-oficial-confira-as-novidades-e-iphones-compativeis/
# Notícia encontrada: https://tecnoblog.net/noticias/apple-reduz-preco-do-iphone-15-em-ate-11-no-brasil-apos-chegada-do-16/
# Notícia encontrada: https://tecnoblog.net/noticias/apple-lanca-airpods-4-com-cancelamento-de-ruido-ativo/
# Notícia encontrada: https://tecnoblog.net/noticias/apple-watch-10-ganha-tela-maior-e-design-mais-fino/
# Notícia encontrada: https://tecnoblog.net/noticias/assim-sao-os-chips-a18-e-a18-pro-que-equipam-os-iphones-16/
# Notícia encontrada: https://tecnoblog.net/noticias/samsung-galaxy-s25-ultra-pode-ter-nova-lente-ultra-angular/
# Notícia encontrada: https://tecnoblog.net/noticias/huawei-lanca-o-huawei-mate-xt-primeiro-celular-dobravel-de-tres-telas/
# Notícia encontrada: https://tecnoblog.net/noticias/google-testa-plano-one-lite-barato-que-oferece-30-gb-de-armazenamento/
# Notícia encontrada: https://tecnoblog.net/noticias/onda-de-calor-traz-riscos-aos-celulares-saiba-como-se-proteger/
# Notícia encontrada: https://tecnoblog.net/noticias/australia-planeja-idade-minima-para-acessar-redes-sociais/
# Notícia encontrada: https://tecnoblog.net/noticias/google-tenta-mas-nao-consegue-escapar-de-multa-bilionaria-na-europa/
# Notícia encontrada: https://tecnoblog.net/noticias/playstation-5-pro-e-anunciado-pela-sony/
# Notícia encontrada: https://tecnoblog.net/noticias/anatel-amplia-0303-e-ameaca-bloquear-empresas-que-ligam-demais/
# Notícia encontrada: https://tecnoblog.net/noticias/google-chrome-vai-sincronizar-grupos-de-abas-entre-o-celular-e-o-desktop/
# Notícia encontrada: https://tecnoblog.net/noticias/iphone-14-tambem-fica-mais-barato-no-brasil-confira-precos/
# Notícia encontrada: https://tecnoblog.net/noticias/nubank-encerra-compra-e-venda-de-nucoins-programa-sera-reformulado/
# Sitemap de notícias encontrado: https://tecnoblog.net/noticias-sitemap29.xml
# Notícia encontrada: https://tecnoblog.net/noticias/drone-dji-neo-desembarca-no-brasil/
# Notícia encontrada: https://tecnoblog.net/noticias/gopro-lanca-hero-13-black-e-nova-camera-compacta-no-brasil/
# Notícia encontrada: https://tecnoblog.net/noticias/certificacao-confirma-galaxy-s25-ultra-com-conexao-via-satelite/
# Notícia encontrada: https://tecnoblog.net/noticias/galaxy-s24-fe-e-homologado-pela-anatel-e-deve-ser-lancado-em-breve/
# Notícia encontrada: https://tecnoblog.net/noticias/flipper-zero-famoso-por-clonar-nfc-ganha-novos-poderes-apos-atualizacao/
# Notícia encontrada: https://tecnoblog.net/noticias/ex-executivos-da-samsung-sao-presos-por-passar-segredos-industriais-a-china/
# Notícia encontrada: https://tecnoblog.net/noticias/apple-anuncia-iphone-16-com-apple-intelligence-e-nova-camera/
# Notícia encontrada: https://tecnoblog.net/noticias/google-mostrara-links-para-paginas-antigas-guardadas-no-internet-archive/
# Notícia encontrada: https://tecnoblog.net/noticias/galaxy-a16-5g-pode-chegar-com-este-visual/
# Notícia encontrada: https://tecnoblog.net/noticias/notebooklm-do-google-podera-gerar-podcasts-para-ajudar-nos-estudos/
# Notícia encontrada: https://tecnoblog.net/noticias/mercado-livre-fica-fora-do-ar-mercado-pago-tambem-sofre-pane/
# Notícia encontrada: https://tecnoblog.net/noticias/gov-br-e-sites-do-governo-ficam-fora-do-ar-nesta-quarta-feira-11/
# Notícia encontrada: https://tecnoblog.net/noticias/rival-do-x-twitter-bluesky-agora-suporta-videos-de-ate-60-segundos/
# Notícia encontrada: https://tecnoblog.net/noticias/youtube-esta-mostrando-anuncios-em-videos-pausados-para-mais-usuarios/
# Notícia encontrada: https://tecnoblog.net/noticias/ue-vai-investigar-como-o-google-treinou-a-ia-palm-2/
# Notícia encontrada: https://tecnoblog.net/noticias/por-que-o-iphone-16-ficou-mais-caro-no-brasil-alta-chega-a-144/
# Notícia encontrada: https://tecnoblog.net/noticias/google-chrome-para-android-vai-facilitar-a-remocao-de-notificacoes-chatas/
# Notícia encontrada: https://tecnoblog.net/noticias/app-do-banco-inter-le-chaves-pix-mesmo-sem-qr-code/
# Notícia encontrada: https://tecnoblog.net/noticias/openai-apresenta-o1-modelo-de-ia-com-raciocinio-logico-aprimorado/
# Notícia encontrada: https://tecnoblog.net/noticias/samsung-promete-one-ui-6-1-1-para-diversos-celulares-no-brasil-veja-lista/
# Notícia encontrada: https://tecnoblog.net/noticias/android-15-vai-aumentar-restricoes-sobre-apps-instalados-via-sideloading/
# Notícia encontrada: https://tecnoblog.net/noticias/microsoft-tem-planos-para-evitar-outro-apagao-no-estilo-crowdstrike/
# Notícia encontrada: https://tecnoblog.net/noticias/anatel-quer-parar-de-homologar-celulares-apenas-com-2g-ou-3g/

# %% [markdown]
# # Resumo do Exercício - Consultando o Sitemap do Tecnoblog
#
# ## O que fizemos:
#
# 1. **Acessamos o arquivo `robots.txt`** do site `https://tecnoblog.net/` para identificar o **sitemap_index.xml**.
#    - O arquivo `robots.txt` nos ajuda a descobrir quais URLs são permitidos para scraping, além de indicar o link do sitemap.
#
# 2. **Realizamos uma requisição HTTP** para acessar o `sitemap_index.xml` usando a biblioteca `requests`.
#    - Para simular um navegador e evitar bloqueios, incluímos um **header de User-Agent** para parecer que estamos acessando o site de um navegador real.
#
# 3. **Filtramos os sitemaps relevantes**, ou seja, aqueles que contêm notícias.
#    - Para isso, usamos o `BeautifulSoup` para analisar o XML retornado e identificamos URLs que contêm "noticia" ou "news" na sua estrutura.
#
# 4. **Extraímos os links das páginas de notícias**:
#    - Para cada sitemap de notícias encontrado, fizemos outra requisição e extraímos todos os links das notícias disponíveis no sitemap.
#
# ## Por que simulamos um navegador?
#
# Simular o acesso de um navegador real por meio de um **User-Agent** é importante porque muitos sites restringem acessos feitos por bots. Sem essa simulação, a requisição poderia ser bloqueada ou retornaria uma resposta inadequada, como vimos no erro 403 que enfrentamos antes de ajustar o código.
#
# Essa abordagem de simulação é bastante comum em web scraping, pois ajuda a evitar restrições impostas por mecanismos de segurança do site.
#
# ## Lógica por trás:
#
# 1. **Consulta ao `robots.txt`**:
#    - Identificamos se o site permite a indexação e scraping. O arquivo também nos dá a rota para o **sitemap**, que é um índice de todas as URLs do site organizadas de forma estruturada.
#
# 2. **Requisições para o Sitemap**:
#    - Uma vez que temos o link do `sitemap_index.xml`, podemos explorar todas as páginas de notícias de maneira eficiente.
#    - Filtramos apenas os sitemaps que contêm notícias, garantindo que os dados extraídos sejam relevantes ao nosso objetivo.
#
# 3. **Scraping Estruturado**:
#    - Usar um sitemap é uma abordagem eficiente porque ele já organiza as URLs do site, permitindo que o scraping seja feito de maneira sistemática e menos propensa a erros.
#
# ## Uso Comercial:
#
# Essa abordagem pode ser utilizada em **estratégias de inteligência competitiva**, onde uma empresa coleta dados de notícias de concorrentes ou do setor para:
# - **Monitorar tendências de mercado**.
# - **Acompanhar notícias relevantes para tomada de decisão**.
# - **Análise de reputação**, observando como seu nome ou produtos estão sendo mencionados na mídia.
#
# Além disso, empresas podem usar essa técnica para **agregação de conteúdo**, automatizando a coleta de links de notícias para gerar insights, relatórios ou alimentar outros sistemas.

# %% [markdown]
# # Parte 5 Scrapy
#
# ## Exercício 11:
#
# Escolha um dos sites de exemplo em https://toscrape.com/ para criar um projeto no Scrapy que obtenha os principais dados disponíveis, salvando em CSV ou JSON conforme a conveniência em relação aos dados do site escolhido.

# %%
pip install -q scrapy
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # Scrapy: Introdução, Passo a Passo e Aplicação Comercial
#
# Scrapy é um framework de web scraping e crawling desenvolvido em Python, projetado para extrair grandes volumes de dados de websites. Ele se destaca por sua eficiência, pois faz múltiplas requisições simultâneas, coletando dados de forma rápida e escalável. Ao contrário de ferramentas como Selenium, que simula a interação do usuário em um navegador, o Scrapy foca diretamente na obtenção de informações estruturadas (HTML) e trabalha em segundo plano, sem a necessidade de renderizar as páginas inteiras, tornando-o mais leve e performático.
#
# ### Passo a Passo
#
# 1. **Instalação do Scrapy**: O primeiro passo foi instalar o Scrapy utilizando o comando `pip install scrapy` no terminal. Essa instalação configura o ambiente para criar e rodar projetos de scraping.
#
# 2. **Criação do Projeto**: Utilizamos o comando `scrapy startproject bookscraper` para iniciar um novo projeto chamado `bookscraper`. Esse comando gera a estrutura necessária para o desenvolvimento, com pastas como `spiders`, onde serão criados os scripts que definem os robôs (spiders).
#
# 3. **Criação do Spider**: Para começar o scraping, criamos um spider que coleta dados de um site específico, no caso, o site **Books to Scrape**. Isso foi feito com o comando `scrapy genspider books toscrape.com`, gerando um arquivo onde configuramos os detalhes do scraping, como as URLs iniciais, os domínios permitidos e a lógica para extrair os dados.
#
# 4. **Execução e Salvamento dos Dados**: Após configurar o spider, executamos o scraping com `scrapy crawl books`, e o Scrapy percorre todas as páginas definidas, extraindo os dados de interesse, como títulos, preços e disponibilidade dos livros. Os dados podem ser salvos em formatos como JSON ou CSV, usando o comando `scrapy crawl books -o books.json` para exportar as informações coletadas para um arquivo.
#
# ### Aplicação Comercial
#
# O uso comercial do Scrapy é vasto. Um exemplo prático seria a construção de sistemas de monitoramento de preços para e-commerces, onde um spider coleta diariamente os preços de produtos dos concorrentes e gera relatórios que permitem a empresa ajustar suas estratégias de precificação de forma dinâmica. Essa automação proporciona insights valiosos com baixo custo de operação.

# %% [markdown]
# ## Exercício 12:
#
# Escolha um dos sites utilizados nas questões 6, 7, 8 e 9 para montar um projeto no Scrapy que abarque tanto o Crawling quanto o Scraping, a fim de rodá-lo tal como na questão anterior.

# %% [markdown]
# ## Para este exercício, vamos utilizamos o site CNN do exercício 9. Os resultados foram salvos em json no diretório do projeto
